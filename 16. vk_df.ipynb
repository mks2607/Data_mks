# %% [markdown]
# <a href="https://colab.research.google.com/github/mks2607/Data_Scientist/blob/mks2607/vk_df.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/winequality-dataset_updated.csv')

# %%
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.3              0.70         0.00            1.90      0.076
# 1               7.8              0.88         0.00            2.60      0.098
# 2               7.8              0.76         0.04            2.30      0.092
# 3              11.2              0.28         0.56            1.90      0.075
# 4               7.2              0.70         0.00            1.90      0.076
# ...             ...               ...          ...             ...        ...
# 1994            9.0              0.45         0.12           15.92      0.049
# 1995           10.0              0.78         0.10           12.15      0.017
# 1996           11.0              0.74         0.14            8.12      0.026
# 1997           15.0              0.62         0.19            1.81      0.027
# 1998            5.0              0.43         0.13            5.11      0.048
#
# ...

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.3              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.2              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
df.tail()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1994            9.0              0.45         0.12           15.92      0.049
# 1995           10.0              0.78         0.10           12.15      0.017
# 1996           11.0              0.74         0.14            8.12      0.026
# 1997           15.0              0.62         0.19            1.81      0.027
# 1998            5.0              0.43         0.13            5.11      0.048
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 1994                 67.0                  62.0  0.99520  2.75       0.49
# 1995                 37.0                  37.0  0.99579  2.46       1.22
# 1996                 52.0                  18.0  0.99897  3.49       0.92
# 1997                 17.0                  54.0  0.99471  2.67       0.76
# 1998                 64.0                 149.0  0.99607  3.30       0.46
#
#       alcohol  quality
# 1994      9.9        9
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1999 entries, 0 to 1998
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1999 non-null   float64
#  1   volatile acidity      1999 non-null   float64
#  2   citric acid           1999 non-null   float64
#  3   residual sugar        1999 non-null   float64
#  4   chlorides             1999 non-null   float64
#  5   free sulfur dioxide   1999 non-null   float64
#  6   total sulfur dioxide  1999 non-null   float64
#  7   density               1999 non-null   float64
#  8   pH                    1999 non-null   float64
#  9   sulphates             1999 non-null   float64
#  10  alcohol               1999 non-null   float64
#  11  quality               1999 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 187.5 KB

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1999.000000       1999.000000  1999.000000     1999.000000
# mean        8.670335          0.541773     0.246668        3.699090
# std         2.240023          0.180381     0.181348        3.290201
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.400000     0.110000        2.000000
# 50%         8.000000          0.530000     0.200000        2.300000
# 75%         9.900000          0.660000     0.385000        3.460000
# max        15.900000          1.580000     1.000000       15.990000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1999.000000          1999.000000           1999.000000  1999.000000
# mean      0.075858            20.191096             52.617809     0.996477
# std       0.048373            15.642224             37.051121     0.002110
# ...

# %%
fixed_acidity	= (df.groupby('fixed acidity').mean())
fixed_acidity
# Out:
#                volatile acidity  citric acid  residual sugar  chlorides  \
# fixed acidity
# 4.6                    0.520000     0.150000        2.100000   0.054000
# 4.7                    0.600000     0.170000        2.300000   0.058000
# 4.9                    0.420000     0.000000        2.100000   0.048000
# 5.0                    0.610952     0.149524        7.855238   0.034238
# 5.1                    0.496250     0.050000        1.725000   0.041000
# ...                         ...          ...             ...        ...
# 14.3                   0.310000     0.740000        1.800000   0.075000
# 15.0                   0.607959     0.166531        8.113878   0.029061
# 15.5                   0.645000     0.490000        4.200000   0.095000
# 15.6                   0.665000     0.625000        3.950000   0.097500
# 15.9                   0.360000     0.650000        7.500000   0.096000
#
#                free sulfur dioxide  total sulfur dioxide   density        pH  \
# ...

# %%
df.groupby('fixed acidity')

# %%
agg_fixed_acidity = (fixed_acidity.agg({"residual sugar": ['sum','mean','count','median']}))

agg_fixed_acidity
# Out:
#         residual sugar
# sum         302.222000
# mean          3.148146
# count        96.000000
# median        2.556579

# %%
df_vk = pd.read_csv('/content/infos.csv')
# Out:
# <ipython-input-27-426a13caedcd>:1: DtypeWarning: Columns (18) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_vk = pd.read_csv('/content/infos.csv')

# %%
df_vk
# Out:
#                id                                               name  \
# 0       133684978                                   Петруха Беларусь
# 1       176149977                            ВСЕ ДО 1000 СЕВАСТОПОЛЬ
# 2        93769112                  VPA | LIKE TIME [ K-pop ° Anime ]
# 3       191929823            Ручная коррекция фигуры. Пластика тела.
# 4         5290065      Свадебный Фотограф Рим Санторини Монако Париж
# ...           ...                                                ...
# 472520   44983609              Магазин электротоваров —  Электроград
# 472521    8248148  БЕСПЛАТНЫЕ ОНЛАЙН-КОНСУЛЬТАЦИИ. Компьютерная п...
# 472522    9165699                 Лучшие порнофильмы! Только новинки
# 472523  109079233                                  Hentai/2d/3d/Pron
# 472524   60882705          Республиканская станция переливания крови
#
#                            screen_name  is_closed   type  \
# 0                           petruha_by          0  group
# ...

# %%
df_vk.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 472525 entries, 0 to 472524
# Data columns (total 19 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   id             472525 non-null  int64
#  1   name           472446 non-null  object
#  2   screen_name    472525 non-null  object
#  3   is_closed      472525 non-null  int64
#  4   type           472525 non-null  object
#  5   city           238121 non-null  object
#  6   country        284120 non-null  object
#  7   description    365303 non-null  object
#  8   members_count  472491 non-null  float64
#  9   activity       472491 non-null  object
#  10  status         347878 non-null  object
#  11  fixed_post     279548 non-null  float64
#  12  verified       472491 non-null  float64
#  13  site           180872 non-null  object
#  14  photo_50       472525 non-null  object
#  15  photo_100      472525 non-null  object
#  16  photo_200      472525 non-null  object
# ...

# %%
open_group = df_vk.groupby('activity').count()
open_group
# Out:
#                              id   name  screen_name  is_closed   type  city  \
# activity
# DJ                          258    258          258        258    258    72
# R&B                          71     71           71         71     71    14
# Rap, Hip-Hop               1338   1338         1338       1338   1338   356
# Авиакомпания                 14     14           14         14     14     4
# Автовладельцы              1147   1147         1147       1147   1147   480
# ...                         ...    ...          ...        ...    ...   ...
# Юмор                      11028  11021        11028      11028  11028  1287
# Юридическая консультация     10     10           10         10     10     2
# Юридические услуги          239    239          239        239    239   155
# Юриспруденция                14     14           14         14     14     5
# Языки                       293    293          293        293    293    69
#
# ...

# %%
country_group = df_vk.groupby('country').count()
country_group
# Out:
#                                                         id    name  \
# country
# {'id': 1, 'title': 'Россия'}                        235125  235114
# {'id': 10, 'title': 'Канада'}                          102     102
# {'id': 101, 'title': 'Конго, демократическая ре...       2       2
# {'id': 102, 'title': 'Коста-Рика'}                       4       4
# {'id': 103, 'title': "Кот-д'Ивуар"}                      4       4
# ...                                                    ...     ...
# {'id': 94, 'title': 'Кения'}                             1       1
# {'id': 95, 'title': 'Кипр'}                             93      93
# {'id': 97, 'title': 'Китай'}                           390     390
# {'id': 98, 'title': 'Колумбия'}                          8       8
# {'id': 99, 'title': 'Коморы'}                            1       1
#
#                                                     screen_name  is_closed  \
# country
# ...

# %%
df_vk.sort_values(by='country',ascending=True)
# Out:
#                id                                         name  \
# 242112   15996149        Поставщики|САДОВОД|ТК МОСКВА|Люблино|
# 312535   35748857            АЛХИМИЯ В ЭНЕРГИЯХ НОВОГО ВРЕМЕНИ
# 312539   96459151        Ищу модель ٨ Ищу мастера٨  Красноярск
# 312541   45223445  Аренда платьев на фотосессии. Пошив платьев
# 312543   79968445                    INJI / Бронь: 89002028385
# ...           ...                                          ...
# 472504   73281076                                        ELECT
# 472507   76871239                                  Piss throat
# 472511   96354835                                 sketch books
# 472519  138569308             ВСЕ НА ФУТБОЛ | ЛЧ | АПЛ | РПЛ |
# 472523  109079233                            Hentai/2d/3d/Pron
#
#              screen_name  is_closed   type  \
# 242112         shopvteme          0   page
# 312535        alhimia888          0  group
# 312539        modelskrsk          0   page
# ...

# %%
df_country = df_vk[df_vk['activity'] == ({'Уход за собой'})]

df_country
# Out:
# Empty DataFrame
# Columns: [id, name, screen_name, is_closed, type, city, country, description, members_count, activity, status, fixed_post, verified, site, photo_50, photo_100, photo_200, start_date, deactivated]
# Index: []

# %%
df_list_1 = df_vk[['city','name','type','country','members_count','fixed_post','start_date']]

df_list_1
# Out:
#                                       city  \
# 0            {'id': 282, 'title': 'Минск'}
# 1                                      NaN
# 2        {'id': 1914764, 'title': 'Tokyo'}
# 3             {'id': 1, 'title': 'Москва'}
# 4       {'id': 1955477, 'title': 'Milano'}
# ...                                    ...
# 472520       {'id': 56, 'title': 'Ижевск'}
# 472521        {'id': 1, 'title': 'Москва'}
# 472522        {'id': 1, 'title': 'Москва'}
# 472523                                 NaN
# 472524       {'id': 56, 'title': 'Ижевск'}
#
#                                                      name   type  \
# 0                                        Петруха Беларусь  group
# 1                                 ВСЕ ДО 1000 СЕВАСТОПОЛЬ   page
# 2                       VPA | LIKE TIME [ K-pop ° Anime ]  group
# 3                 Ручная коррекция фигуры. Пластика тела.   page
# 4           Свадебный Фотограф Рим Санторини Монако Париж  group
# ...

# %%
df_list_2 = df_list_1[df_list_1['members_count'] > 3000000]

df_list_2
# Out:
#                                 city                                name  \
# 205375                           NaN  Новинки Музыки 2020 | Новая Музыка
# 205376                           NaN        Киномания ► Фильмы и сериалы
# 205377  {'id': 1, 'title': 'Москва'}                           Киномания
# 205378                           NaN            КиноКайф - Лучшие фильмы
# 205379  {'id': 1, 'title': 'Москва'}                  Леонардо Дайвинчик
# ...                              ...                                 ...
# 205578                           NaN                                Сбер
# 205579                           NaN                                 MDK
# 205580                           NaN    Прически | Стрижки 💇 Окрашивания
# 205581                           NaN                  Психология о жизни
# 205582                           NaN                          Они тупые?
#
#         type                       country  members_count  fixed_post  \
# ...

# %%
df_list_2.isna().sum()
# Out:
# city             187
# name               0
# type               0
# country          171
# members_count      0
# fixed_post        45
# start_date        15
# dtype: int64

# %%
df_list_3 = df_list_2[df_list_1['fixed_post'] > 10000000]

df_list_3
# Out:
# <ipython-input-99-83c0e4ca820f>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_list_3 = df_list_2[df_list_1['fixed_post'] > 10000000]
#                                  city                                name  \
# 205375                            NaN  Новинки Музыки 2020 | Новая Музыка
# 205376                            NaN        Киномания ► Фильмы и сериалы
# 205380                            NaN                                 MDK
# 205383                            NaN                   Смейся до слёз :D
# 205390                            NaN                         Я тебя хочу
# 205397                            NaN                                БОРЩ
# 205422                            NaN                            NR.Music
# 205431                            NaN                       Овсянка, сэр!
# 205465                            NaN                       Рифмы и Панчи
# ...

# %%
df_list_3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 17 entries, 205375 to 205579
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   city           1 non-null      object
#  1   name           17 non-null     object
#  2   type           17 non-null     object
#  3   country        4 non-null      object
#  4   members_count  17 non-null     float64
#  5   fixed_post     17 non-null     float64
#  6   start_date     16 non-null     float64
# dtypes: float64(3), object(4)
# memory usage: 1.1+ KB
