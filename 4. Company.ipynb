# %% [markdown]
# <a href="https://colab.research.google.com/github/mks2607/Data_Scientist/blob/mks2607/Company.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_dividend = pd.read_csv('/content/Companies_ranked_by_Dividend_Yield.csv')
df_eaning = pd.read_csv('/content/Companies_ranked_by_Earnings.csv')
df_market = pd.read_csv('/content/Companies_ranked_by_Market_Cap.csv')
df_p_e_ratio = pd.read_csv('/content/Companies_ranked_by_P_E_ratio.csv')
df_revenue = pd.read_csv('/content/Companies_ranked_by_Revenue.csv')

# %%
df_revenue.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9912 entries, 0 to 9911
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Rank         9912 non-null   int64
#  1   Name         9912 non-null   object
#  2   Symbol       9911 non-null   object
#  3   revenue_ttm  9912 non-null   int64
#  4   price (GBP)  9912 non-null   float64
#  5   country      9910 non-null   object
# dtypes: float64(1), int64(2), object(3)
# memory usage: 464.8+ KB

# %%
df_p_e_ratio.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9912 entries, 0 to 9911
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rank          9912 non-null   int64
#  1   Name          9912 non-null   object
#  2   Symbol        9911 non-null   object
#  3   pe_ratio_ttm  9912 non-null   float64
#  4   price (GBP)   9912 non-null   float64
#  5   country       9910 non-null   object
# dtypes: float64(2), int64(1), object(3)
# memory usage: 464.8+ KB

# %%
df_dividend.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9912 entries, 0 to 9911
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Rank                9912 non-null   int64
#  1   Name                9912 non-null   object
#  2   Symbol              9911 non-null   object
#  3   dividend_yield_ttm  9912 non-null   float64
#  4   price (GBP)         9912 non-null   float64
#  5   country             9910 non-null   object
# dtypes: float64(2), int64(1), object(3)
# memory usage: 464.8+ KB

# %%
df_eaning.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9912 entries, 0 to 9911
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rank          9912 non-null   int64
#  1   Name          9912 non-null   object
#  2   Symbol        9911 non-null   object
#  3   earnings_ttm  9912 non-null   float64
#  4   price (GBP)   9912 non-null   float64
#  5   country       9910 non-null   object
# dtypes: float64(2), int64(1), object(3)
# memory usage: 464.8+ KB

# %%
df_market.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9912 entries, 0 to 9911
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Rank         9912 non-null   int64
#  1   Name         9912 non-null   object
#  2   Symbol       9911 non-null   object
#  3   marketcap    9912 non-null   float64
#  4   price (GBP)  9912 non-null   float64
#  5   country      9910 non-null   object
# dtypes: float64(2), int64(1), object(3)
# memory usage: 464.8+ KB

# %%
df_dividend.head(3)
# Out:
#    Rank            Name    Symbol  dividend_yield_ttm  price (GBP)  \
# 0     1         LianBio      LIAN            300940.0     0.243065
# 1     2  Richter Gedeon    RIG2.F            150430.0    23.726825
# 2     3     Delek Group  DLEKG.TA            117114.0    87.735884
#
#          country
# 0  United States
# 1        Hungary
# 2         Israel

# %%
df_market.head(3)
# Out:
#    Rank       Name Symbol     marketcap  price (GBP)        country
# 0     1      Apple   AAPL  2.689903e+12   176.919492  United States
# 1     2  Microsoft   MSFT  2.427170e+12   326.537958  United States
# 2     3     NVIDIA   NVDA  2.259353e+12    92.105725  United States

# %%
df_eaning.head(3)
# Out:
#    Rank          Name   Symbol  earnings_ttm  price (GBP)        country
# 0     1  Saudi Aramco  2222.SR  2.283780e+11     5.505405   Saudi Arabia
# 1     2         Apple     AAPL  1.216250e+11   176.734336  United States
# 2     3     Microsoft     MSFT  1.077870e+11   326.461762  United States

# %%
df_p_e_ratio.head(10)
# Out:
#    Rank                  Name   Symbol  pe_ratio_ttm  price (GBP)  \
# 0     1    Imperial Petroleum     IMPP      0.109943     3.108797
# 1     2         Vertex Energy     VTNR      0.188889     0.092197
# 2     3           Spin Master   TOY.TO      0.224758    17.414443
# 3     4  Performance Shipping     PSHG      0.225293     1.467916
# 4     5        TherapeuticsMD     TXMD      0.340956     1.280093
# 5     6              Chimerix     CMRX      0.433204     0.684926
# 6     7           Tingo Group      TIO      0.456954     0.525752
# 7     8        Canacol Energy   CNE.TO      0.462276     2.005471
# 8     9             CR Energy  CRZK.DE      0.517095     5.083111
# 9    10          Vital Energy     VTLE      0.532125    20.336712
#
#          country
# 0         Greece
# 1  United States
# 2         Canada
# 3         Greece
# 4  United States
# 5  United States
# 6  United States
# 7         Canada
# 8        Germany
# 9  United States

# %%
df_revenue.head(10)
# Out:
#    Rank                Name     Symbol   revenue_ttm  price (GBP)  \
# 0     1             Walmart        WMT  665035000000    61.029186
# 1     2              Amazon       AMZN  604334000000   143.454209
# 2     3        Saudi Aramco    2222.SR  495354806850     5.505405
# 3     4             Sinopec  600028.SS  435696880608     0.748295
# 4     5          PetroChina  601857.SS  429671599508     0.969769
# 5     6  Berkshire Hathaway      BRK-B  402877000000   347.537576
# 6     7               Apple       AAPL  385603000000   176.706906
# 7     8        UnitedHealth        UNH  381255000000   441.487244
# 8     9          CVS Health        CVS  363248000000    47.729174
# 9    10          Volkswagen    VOW3.DE  350679303398    79.995895
#
#          country
# 0  United States
# 1  United States
# 2   Saudi Arabia
# 3          China
# 4          China
# 5  United States
# 6  United States
# 7  United States
# 8  United States
# 9        Germany

# %%
new_table = df_dividend

new_table = pd.merge(new_table,df_eaning, on='Name', how='outer')
new_table = pd.merge(new_table,df_market, on='Name', how='outer')
new_table = pd.merge(new_table,df_p_e_ratio, on='Name', how='outer',suffixes=('_df1', '_rat'))
new_table = pd.merge(new_table,df_revenue, on='Name', how='outer',suffixes=('_df1', '_rev'))


# Объединение с использованием суффиксов
#result = pd.merge(df1, df2, on='Symbol', how='outer', suffixes=('_df1', '_df2'))

# %% [markdown]
# Параметр suffixes=('_df1', '_df2') указывает, что к именам дублирующихся столбцов из первого DataFrame будет добавлен суффикс _df1, а к именам дублирующихся столбцов из второго DataFrame — суффикс _df2. Это позволяет избежать конфликтов имен и сохранить все данные.

# %%
new_table
# Out:
#        Rank_x                                               Name  Symbol_x  \
# 0        6706  (DIA) Distribuidora Internacional de Alimentación    DIA.MC
# 1        2229                           (HLBank) Hong Leong Bank   5819.KL
# 2        9795                                          029 Group    Z29.DE
# 3        4306                                                1&1    1U1.DE
# 4        5620                                      1-800-Flowers      FLWS
# ...       ...                                                ...       ...
# 9997      739                                          ČEZ Group    CEZ.PR
# 9998     3366                                            İsdemir  ISDMR.IS
# 9999     6282                                      İşbir Holding  ISBIR.IS
# 10000    2988                                            Şişecam   SISE.IS
# 10001    1747                                           “K” Line    9107.T
#
#        dividend_yield_ttm  price (GBP)_x       country_x  Rank_y  Symbol_y  \
# 0                  0.0000       0.010892           Spain    9147    DIA.MC
# 1                268.6790       3.795719        Malaysia    1237   5819.KL
# 2                  0.0000      12.496677         Germany    7526    Z29.DE
# 3                 35.9754      11.567848         Germany    2190    1U1.DE
# 4                  0.0000       6.084251   United States    6616      FLWS
# ...                   ...            ...             ...     ...       ...
# 9997             574.7580      29.800408  Czech Republic     372    CEZ.PR
# 9998             133.4360       0.884293          Turkey    2143  ISDMR.IS
# 9999               0.0000       2.336299          Turkey    7281  ISBIR.IS
# 10000            173.0410       0.974874          Turkey    1938   SISE.IS
# 10001            333.6210      11.842154           Japan    1313    9107.T
#
#        earnings_ttm  price (GBP)_y  ... Rank_rat  Symbol_rat pe_ratio_ttm  \
# 0     -1.089970e+08       0.010892  ...     7382      DIA.MC    -0.621711
# 1      1.048330e+09       3.795719  ...     8577     5819.KL    11.790000
# 2     -6.217810e+06      12.496677  ...     9853      Z29.DE  -115.433000
# 3      4.516690e+08      11.567848  ...      626      1U1.DE     7.247400
# 4      4.721000e+06       6.084251  ...     5913        FLWS   -11.536200
# ...             ...            ...  ...      ...         ...          ...
# 9997   4.102380e+09      29.800408  ...      565      CEZ.PR     6.884740
# 9998   4.680210e+08       0.884293  ...     6700    ISDMR.IS   -38.206400
# 9999  -1.685470e+06       2.336299  ...     6707    ISBIR.IS -8391.710000
# 10000  5.504870e+08       0.974874  ...      239     SISE.IS     4.287800
# 10001  9.734360e+08      11.842154  ...       34      9107.T     1.227210
#
#        price (GBP)_rat     country_rat  Rank    Symbol  revenue_ttm  \
# 0             0.010892           Spain  1335    DIA.MC   7807745770
# 1             3.795719        Malaysia  3980   5819.KL   1175958513
# 2            12.496677         Germany  9870    Z29.DE            0
# 3            11.567848         Germany  2009    1U1.DE   4446071725
# 4             6.084251   United States  3307      FLWS   1831421000
# ...                ...             ...   ...       ...          ...
# 9997         29.800408  Czech Republic   871    CEZ.PR  13392749165
# 9998          0.884293          Turkey  2225  ISDMR.IS   3811260337
# 9999          2.336299          Turkey  7415  ISBIR.IS    121376591
# 10000         0.974874          Turkey  1687   SISE.IS   5821511758
# 10001        11.842154           Japan  1532    9107.T   6568116808
#
#        price (GBP)         country
# 0         0.010892           Spain
# 1         3.795719        Malaysia
# 2        12.496677         Germany
# 3        11.567848         Germany
# 4         6.084251   United States
# ...            ...             ...
# 9997     29.800408  Czech Republic
# 9998      0.884293          Turkey
# 9999      2.336299          Turkey
# 10000     0.974874          Turkey
# 10001    11.842154           Japan
#
# [10002 rows x 26 columns]

# %%
new_table.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10002 entries, 0 to 10001
# Data columns (total 26 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Rank_x              10002 non-null  int64
#  1   Name                10002 non-null  object
#  2   Symbol_x            10001 non-null  object
#  3   dividend_yield_ttm  10002 non-null  float64
#  4   price (GBP)_x       10002 non-null  float64
#  5   country_x           10000 non-null  object
#  6   Rank_y              10002 non-null  int64
#  7   Symbol_y            10001 non-null  object
#  8   earnings_ttm        10002 non-null  float64
#  9   price (GBP)_y       10002 non-null  float64
#  10  country_y           10000 non-null  object
#  11  Rank_df1            10002 non-null  int64
#  12  Symbol_df1          10001 non-null  object
#  13  marketcap           10002 non-null  float64
#  14  price (GBP)_df1     10002 non-null  float64
#  15  country_df1         10000 non-null  object
#  16  Rank_rat            10002 non-null  int64
#  17  Symbol_rat          10001 non-null  object
#  18  pe_ratio_ttm        10002 non-null  float64
#  19  price (GBP)_rat     10002 non-null  float64
#  20  country_rat         10000 non-null  object
#  21  Rank                10002 non-null  int64
#  22  Symbol              10001 non-null  object
#  23  revenue_ttm         10002 non-null  int64
#  24  price (GBP)         10002 non-null  float64
#  25  country             10000 non-null  object
# dtypes: float64(9), int64(6), object(11)
# memory usage: 2.0+ MB

# %%
new_table = new_table.drop(columns=['Rank_x', 'Rank_y', 'Rank_df1','Rank_rat','Rank']) # Удаляем столбцы 'A' и 'B'

# %%
new_table = new_table.drop(columns=['Symbol_rat','Symbol_df1','Symbol_y','Symbol_x','country_rat','country_df1','country_y','country_x'])

# %%
new_table.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10002 entries, 0 to 10001
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Name                10002 non-null  object
#  1   dividend_yield_ttm  10002 non-null  float64
#  2   price (GBP)_x       10002 non-null  float64
#  3   earnings_ttm        10002 non-null  float64
#  4   price (GBP)_y       10002 non-null  float64
#  5   marketcap           10002 non-null  float64
#  6   price (GBP)_df1     10002 non-null  float64
#  7   pe_ratio_ttm        10002 non-null  float64
#  8   price (GBP)_rat     10002 non-null  float64
#  9   Symbol              10001 non-null  object
#  10  revenue_ttm         10002 non-null  int64
#  11  price (GBP)         10002 non-null  float64
#  12  country             10000 non-null  object
# dtypes: float64(9), int64(1), object(3)
# memory usage: 1016.0+ KB

# %%
new_table = new_table.drop(columns=['price (GBP)_rat','price (GBP)_df1','price (GBP)_y','price (GBP)_x'])

# %%
new_table = new_table.fillna("not country")
new_table
# Out:
#                                                     Name  dividend_yield_ttm  \
# 0      (DIA) Distribuidora Internacional de Alimentación              0.0000
# 1                               (HLBank) Hong Leong Bank            268.6790
# 2                                              029 Group              0.0000
# 3                                                    1&1             35.9754
# 4                                          1-800-Flowers              0.0000
# ...                                                  ...                 ...
# 9997                                           ČEZ Group            574.7580
# 9998                                             İsdemir            133.4360
# 9999                                       İşbir Holding              0.0000
# 10000                                            Şişecam            173.0410
# 10001                                           “K” Line            333.6210
#
#        earnings_ttm     marketcap  pe_ratio_ttm    Symbol  revenue_ttm  \
# 0     -1.089970e+08  6.322133e+08     -0.621711    DIA.MC   7807745770
# 1      1.048330e+09  7.920216e+09     11.790000   5819.KL   1175958513
# 2     -6.217810e+06  6.248342e+07   -115.433000    Z29.DE            0
# 3      4.516690e+08  2.039417e+09      7.247400    1U1.DE   4446071725
# 4      4.721000e+06  3.907330e+08    -11.536200      FLWS   1831421000
# ...             ...           ...           ...       ...          ...
# 9997   4.102380e+09  1.599717e+10      6.884740    CEZ.PR  13392749165
# 9998   4.680210e+08  2.564457e+09    -38.206400  ISDMR.IS   3811260337
# 9999  -1.685470e+06  8.453940e+07  -8391.710000  ISBIR.IS    121376591
# 10000  5.504870e+08  2.986254e+09      4.287800   SISE.IS   5821511758
# 10001  9.734360e+08  7.982348e+09      1.227210    9107.T   6568116808
#
#        price (GBP)         country
# 0         0.010892           Spain
# 1         3.795719        Malaysia
# 2        12.496677         Germany
# 3        11.567848         Germany
# 4         6.084251   United States
# ...            ...             ...
# 9997     29.800408  Czech Republic
# 9998      0.884293          Turkey
# 9999      2.336299          Turkey
# 10000     0.974874          Turkey
# 10001    11.842154           Japan
#
# [10002 rows x 9 columns]

# %%
new_table.sort_values(by = 'price (GBP)', ascending=False)
# Out:
#                                            Name  dividend_yield_ttm  \
# 3166                             Eurofins-Cerep              0.0000
# 3330          Financière Moncey Société anonyme             22.6437
# 5385                             Lotus Bakeries             47.2955
# 2141     Chocoladefabriken Lindt &amp; Sprüngli            120.1740
# 3401                 First National of Nebraska            100.0000
# ...                                         ...                 ...
# 2774              Drake and Scull International              0.0000
# 2791  Dubai Islamic Insurance &amp; Reinsurance              0.0000
# 2794                         Dubai Taxi Company              0.0000
# 3007           Emirates Central Cooling Systems              0.0000
# 403                                  Ajman Bank              0.0000
#
#       earnings_ttm     marketcap  pe_ratio_ttm        Symbol  revenue_ttm  \
# 3166     7873630.0  8.347650e+07       12.9738      ALECR.PA     48717058
# 3330    10463900.0  1.868372e+09        0.0000      FMONC.PA      1460981
# 5385   143767000.0  8.231964e+09       97.5234       LOTB.BR    941218557
# 2141   936654000.0  2.270620e+10       49.7671       LISP.SW   6186314984
# 3401   152625000.0  2.369406e+09       43.0911          FINN    337041000
# ...            ...           ...           ...           ...          ...
# 2774   973366000.0  0.000000e+00       -0.0000        DSI.AE     27101472
# 2791    -3042070.0  0.000000e+00        0.0000       AMAN.AE     -1996760
# 2794    99370300.0  0.000000e+00        0.0000        DTC.AE    568144984
# 3007   326214000.0  0.000000e+00        0.0000    EMPOWER.AE    877080621
# 403    -70798300.0  0.000000e+00        0.0000  AJMANBANK.AE    251470298
#
#        price (GBP)               country
# 3166  16549.695004                France
# 3330  10216.893052                France
# 5385  10132.467884               Belgium
# 2141   9962.093628           Switzerland
# 3401   9143.520000         United States
# ...            ...                   ...
# 2774      0.000000  United Arab Emirates
# 2791      0.000000  United Arab Emirates
# 2794      0.000000  United Arab Emirates
# 3007      0.000000  United Arab Emirates
# 403       0.000000  United Arab Emirates
#
# [10002 rows x 9 columns]

# %%
new_table.sort_values(by = ['price (GBP)', 'marketcap','dividend_yield_ttm','pe_ratio_ttm','Symbol'],ascending=False)
# Out:
#                                         Name  dividend_yield_ttm  \
# 3166                          Eurofins-Cerep              0.0000
# 3330       Financière Moncey Société anonyme             22.6437
# 5385                          Lotus Bakeries             47.2955
# 2141  Chocoladefabriken Lindt &amp; Sprüngli            120.1740
# 3401              First National of Nebraska            100.0000
# ...                                      ...                 ...
# 430             Al Ansari Financial Services              0.0000
# 403                               Ajman Bank              0.0000
# 378                               Air Arabia              0.0000
# 356                           Agility Global              0.0000
# 215                       Abu Dhabi Aviation              0.0000
#
#       earnings_ttm     marketcap  pe_ratio_ttm         Symbol  revenue_ttm  \
# 3166     7873630.0  8.347650e+07       12.9738       ALECR.PA     48717058
# 3330    10463900.0  1.868372e+09        0.0000       FMONC.PA      1460981
# 5385   143767000.0  8.231964e+09       97.5234        LOTB.BR    941218557
# 2141   936654000.0  2.270620e+10       49.7671        LISP.SW   6186314984
# 3401   152625000.0  2.369406e+09       43.0911           FINN    337041000
# ...            ...           ...           ...            ...          ...
# 430    127575000.0  0.000000e+00        0.0000    ALANSARI.AE    308156151
# 403    -70798300.0  0.000000e+00        0.0000   AJMANBANK.AE    251470298
# 378    417502000.0  0.000000e+00        0.0000   AIRARABIA.AE   1735197519
# 356            0.0  0.000000e+00        0.0000     AGILITY.AE            0
# 215            0.0  0.000000e+00        0.0000  ADAVIATION.AE            0
#
#        price (GBP)               country
# 3166  16549.695004                France
# 3330  10216.893052                France
# 5385  10132.467884               Belgium
# 2141   9962.093628           Switzerland
# 3401   9143.520000         United States
# ...            ...                   ...
# 430       0.000000  United Arab Emirates
# 403       0.000000  United Arab Emirates
# 378       0.000000  United Arab Emirates
# 356       0.000000  United Arab Emirates
# 215       0.000000  United Arab Emirates
#
# [10002 rows x 9 columns]

# %%
new_table.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10002 entries, 0 to 10001
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Name                10002 non-null  object
#  1   dividend_yield_ttm  10002 non-null  float64
#  2   earnings_ttm        10002 non-null  float64
#  3   marketcap           10002 non-null  float64
#  4   pe_ratio_ttm        10002 non-null  float64
#  5   Symbol              10002 non-null  object
#  6   revenue_ttm         10002 non-null  int64
#  7   price (GBP)         10002 non-null  float64
#  8   country             10002 non-null  object
# dtypes: float64(5), int64(1), object(3)
# memory usage: 703.4+ KB

# %%
new_table['country'] = new_table['country'].str.upper()

# %%
new_table
# Out:
#                                                     Name  dividend_yield_ttm  \
# 0      (DIA) Distribuidora Internacional de Alimentación              0.0000
# 1                               (HLBank) Hong Leong Bank            268.6790
# 2                                              029 Group              0.0000
# 3                                                    1&1             35.9754
# 4                                          1-800-Flowers              0.0000
# ...                                                  ...                 ...
# 9997                                           ČEZ Group            574.7580
# 9998                                             İsdemir            133.4360
# 9999                                       İşbir Holding              0.0000
# 10000                                            Şişecam            173.0410
# 10001                                           “K” Line            333.6210
#
#        earnings_ttm     marketcap  pe_ratio_ttm    Symbol  revenue_ttm  \
# 0     -1.089970e+08  6.322133e+08     -0.621711    DIA.MC   7807745770
# 1      1.048330e+09  7.920216e+09     11.790000   5819.KL   1175958513
# 2     -6.217810e+06  6.248342e+07   -115.433000    Z29.DE            0
# 3      4.516690e+08  2.039417e+09      7.247400    1U1.DE   4446071725
# 4      4.721000e+06  3.907330e+08    -11.536200      FLWS   1831421000
# ...             ...           ...           ...       ...          ...
# 9997   4.102380e+09  1.599717e+10      6.884740    CEZ.PR  13392749165
# 9998   4.680210e+08  2.564457e+09    -38.206400  ISDMR.IS   3811260337
# 9999  -1.685470e+06  8.453940e+07  -8391.710000  ISBIR.IS    121376591
# 10000  5.504870e+08  2.986254e+09      4.287800   SISE.IS   5821511758
# 10001  9.734360e+08  7.982348e+09      1.227210    9107.T   6568116808
#
#        price (GBP)         country
# 0         0.010892           SPAIN
# 1         3.795719        MALAYSIA
# 2        12.496677         GERMANY
# 3        11.567848         GERMANY
# 4         6.084251   UNITED STATES
# ...            ...             ...
# 9997     29.800408  CZECH REPUBLIC
# 9998      0.884293          TURKEY
# 9999      2.336299          TURKEY
# 10000     0.974874          TURKEY
# 10001    11.842154           JAPAN
#
# [10002 rows x 9 columns]

# %%
new_table['Symbol'] = new_table['Symbol'].str.swapcase()

new_table
# Out:
#                                                     Name  dividend_yield_ttm  \
# 0      (DIA) Distribuidora Internacional de Alimentación              0.0000
# 1                               (HLBank) Hong Leong Bank            268.6790
# 2                                              029 Group              0.0000
# 3                                                    1&1             35.9754
# 4                                          1-800-Flowers              0.0000
# ...                                                  ...                 ...
# 9997                                           ČEZ Group            574.7580
# 9998                                             İsdemir            133.4360
# 9999                                       İşbir Holding              0.0000
# 10000                                            Şişecam            173.0410
# 10001                                           “K” Line            333.6210
#
#        earnings_ttm     marketcap  pe_ratio_ttm    Symbol  revenue_ttm  \
# 0     -1.089970e+08  6.322133e+08     -0.621711    DIA.MC   7807745770
# 1      1.048330e+09  7.920216e+09     11.790000   5819.KL   1175958513
# 2     -6.217810e+06  6.248342e+07   -115.433000    Z29.DE            0
# 3      4.516690e+08  2.039417e+09      7.247400    1U1.DE   4446071725
# 4      4.721000e+06  3.907330e+08    -11.536200      FLWS   1831421000
# ...             ...           ...           ...       ...          ...
# 9997   4.102380e+09  1.599717e+10      6.884740    CEZ.PR  13392749165
# 9998   4.680210e+08  2.564457e+09    -38.206400  ISDMR.IS   3811260337
# 9999  -1.685470e+06  8.453940e+07  -8391.710000  ISBIR.IS    121376591
# 10000  5.504870e+08  2.986254e+09      4.287800   SISE.IS   5821511758
# 10001  9.734360e+08  7.982348e+09      1.227210    9107.T   6568116808
#
#        price (GBP)         country
# 0         0.010892           SPAIN
# 1         3.795719        MALAYSIA
# 2        12.496677         GERMANY
# 3        11.567848         GERMANY
# 4         6.084251   UNITED STATES
# ...            ...             ...
# 9997     29.800408  CZECH REPUBLIC
# 9998      0.884293          TURKEY
# 9999      2.336299          TURKEY
# 10000     0.974874          TURKEY
# 10001    11.842154           JAPAN
#
# [10002 rows x 9 columns]

# %%
grouped_tab = new_table.groupby('country').sum()

grouped_tab
# Out:
#                                                              Name  \
# country
# ARGENTINA       Aluar Aluminio ArgentinoBBVA ArgentinaBanco Ma...
# AUSTRALIA       3P LearningAGL EnergyAIC Mines LimitedALS Glob...
# AUSTRIA         A1 Telekom AustriaAMAG Austria MetallAT&amp;S ...
# BAHAMAS                           Nymox PharmaceuticalOneSpaWorld
# BAHRAIN         APM Terminals BahrainAhli United BankAl Baraka...
# ...                                                           ...
# UNITED KINGDOM  3i Group4basebio4imprint GroupADVFNAFC EnergyA...
# UNITED STATES   1-800-Flowers1-800-PetMeds10x Genomics180 Life...
# URUGUAY                              Arcos Dorados HoldingsdLocal
# USA                                          GRIID Infrastructure
# VIETNAM         Asia Commercial Joint Stock BankBIDV  (Commerc...
#
#                 dividend_yield_ttm  earnings_ttm     marketcap  pe_ratio_ttm  \
# country
# ARGENTINA             3.481066e+03  9.844205e+09  1.275772e+11  5.245290e+02
# AUSTRALIA             3.261930e+04  1.134531e+11  1.346758e+12  6.253797e+03
# AUSTRIA               1.532745e+04  2.642092e+10  1.246062e+11  6.989681e+01
# BAHAMAS               0.000000e+00  6.772800e+07  1.332004e+09 -3.333330e+00
# BAHRAIN               2.379922e+04  3.079841e+09  2.403681e+10  0.000000e+00
# ...                            ...           ...           ...           ...
# UNITED KINGDOM        7.350964e+04  2.315065e+11  2.887930e+12  8.060448e+06
# UNITED STATES         1.005434e+06  2.586901e+12  4.473698e+13 -4.807594e+18
# URUGUAY               2.370200e+02  4.111180e+08  3.170704e+09  2.889300e+01
# USA                   0.000000e+00  2.911000e+07  4.117491e+07  0.000000e+00
# VIETNAM               0.000000e+00  9.216623e+09  9.400906e+10  9.296859e+02
#
#                                                            Symbol  \
# country
# ARGENTINA       ALUA.BABBARBMABIOXCELU.BACEPUDESPFERR.BAGGALSU...
# AUSTRALIA       3PL.AXAGL.AXA1M.AXALQ.AXAMP.AXANZ.AXAPA.AXAPM....
# AUSTRIA         TA1.FAM8.FATS.VIZYE1.FAGR.VIAZ2.FATH.VIACAG.VI...
# BAHAMAS                                                   NYMXOSW
# BAHRAIN         APMTB.BHAUB.BHBARKA.BHSALAM.BHALBH.BHARIG.BHBM...
# ...                                                           ...
# UNITED KINGDOM  III.L4BB.LFOUR.LAFN.LAFC.LAJB.LAO.LASC.LAXS.LA...
# UNITED STATES   FLWSPETSTXGATNFSRCEDIBSXXIIMETWOUTSVTSCWODDDMM...
# URUGUAY                                                   ARCODLO
# USA                                                       GRDI.NE
# VIETNAM         ACB.VNBID.VNBVH.VNBCM.VNDGC.VNEIB.VNFPT.VNGEX....
#
#                    revenue_ttm    price (GBP)
# country
# ARGENTINA          64666622103    1801.716251
# AUSTRALIA         655105652909    2248.084860
# AUSTRIA           201579927856    1655.066279
# BAHAMAS              847194000      12.739971
# BAHRAIN            11326918702      19.625807
# ...                        ...            ...
# UNITED KINGDOM   1796620455361    5463.464935
# UNITED STATES   21785192413577  188659.308085
# URUGUAY             5200457000      12.899983
# USA                   19744000       0.606696
# VIETNAM            69024025803      52.970752
#
# [80 rows x 8 columns]

# %%
grouped_tab = grouped_tab.drop(columns=['Name','Symbol'])

# %%
grouped_tab.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 80 entries, ARGENTINA to VIETNAM
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   dividend_yield_ttm  80 non-null     float64
#  1   earnings_ttm        80 non-null     float64
#  2   marketcap           80 non-null     float64
#  3   pe_ratio_ttm        80 non-null     float64
#  4   revenue_ttm         80 non-null     int64
#  5   price (GBP)         80 non-null     float64
# dtypes: float64(5), int64(1)
# memory usage: 6.4+ KB

# %%
grouped_tab.sort_values(by='price (GBP)',ascending=False)
# Out:
#                dividend_yield_ttm  earnings_ttm     marketcap  pe_ratio_ttm  \
# country
# UNITED STATES        1.005434e+06  2.586901e+12  4.473698e+13 -4.807594e+18
# KUWAIT               0.000000e+00  1.080453e+10  9.838438e+10 -1.113758e+05
# SWITZERLAND          2.417431e+04  1.707284e+11  1.941830e+12  5.046762e+03
# FRANCE               4.704609e+04  2.104839e+11  2.347963e+12  1.983083e+04
# JAPAN                6.793374e+04  4.455330e+11  3.941459e+12  8.139218e+03
# ...                           ...           ...           ...           ...
# NIGERIA              8.038890e+02  1.137820e+09  7.554604e+08  0.000000e+00
# EGYPT                7.888190e+01  1.454500e+09  3.920486e+09  6.237260e+00
# USA                  0.000000e+00  2.911000e+07  4.117491e+07  0.000000e+00
# ESTONIA              1.028230e+03  1.080970e+08  3.666487e+08  4.701750e+00
# SUDAN                0.000000e+00  0.000000e+00  6.941984e+07  0.000000e+00
#
#                   revenue_ttm    price (GBP)
# country
# UNITED STATES  21785192413577  188659.308085
# KUWAIT            45304071860   82663.673444
# SWITZERLAND     1265982386090   65845.488422
# FRANCE          2261628157255   59154.126615
# JAPAN           4377468751777   18706.391073
# ...                       ...            ...
# NIGERIA            1767391607       1.283445
# EGYPT              1935054354       1.199005
# USA                  19744000       0.606696
# ESTONIA             867348288       0.482136
# SUDAN                       0       0.053337
#
# [80 rows x 6 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['dividend_yield_ttm'].plot(kind='hist', bins=20, title='dividend_yield_ttm')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['earnings_ttm'].plot(kind='hist', bins=20, title='earnings_ttm')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_2['marketcap'].plot(kind='hist', bins=20, title='marketcap')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_3['pe_ratio_ttm'].plot(kind='hist', bins=20, title='pe_ratio_ttm')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_4.plot(kind='scatter', x='dividend_yield_ttm', y='earnings_ttm', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_5.plot(kind='scatter', x='earnings_ttm', y='marketcap', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_6.plot(kind='scatter', x='marketcap', y='pe_ratio_ttm', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_7.plot(kind='scatter', x='pe_ratio_ttm', y='revenue_ttm', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_8['dividend_yield_ttm'].plot(kind='line', figsize=(8, 4), title='dividend_yield_ttm')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_9['earnings_ttm'].plot(kind='line', figsize=(8, 4), title='earnings_ttm')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_10['marketcap'].plot(kind='line', figsize=(8, 4), title='marketcap')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_11['pe_ratio_ttm'].plot(kind='line', figsize=(8, 4), title='pe_ratio_ttm')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %%
from matplotlib import pyplot as plt
_df_9['earnings_ttm'].plot(kind='line', figsize=(8, 4), title='earnings_ttm')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
grouped_tab.to_excel('new_grouped_tab.xlsx')

# %% [markdown]
# ТЗ для датасета
#
# 10. Сохраним таблицу в csv
# 11. Сделать простой дашборд в data lens
