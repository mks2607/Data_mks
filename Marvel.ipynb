# %% [markdown]
# <a href="https://colab.research.google.com/github/mks2607/Data_Scientist/blob/mks2607/Marvel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/Marvel Vs DC NEW.csv')

# %%
df
# Out:
#         ID                              Movie         Year  \
# 0        0                           Eternals        -2021
# 1        1                               Loki     (2021– )
# 2        2  The Falcon and the Winter Soldier        -2021
# 3        3                        WandaVision        -2021
# 4        4            Spider-Man: No Way Home        -2021
# ...    ...                                ...          ...
# 1685  1685           DC's Legends of Tomorrow     (2016– )
# 1686  1686                          Supergirl  (2015–2021)
# 1687  1687                          Supergirl  (2015–2021)
# 1688  1688                          Supergirl  (2015–2021)
# 1689  1689                          Supergirl  (2015–2021)
#
#                          Genre  RunTime  \
# 0       Action,Adventure,Drama        0
# 1     Action,Adventure,Fantasy        0
# 2       Action,Adventure,Drama   50 min
# 3          Action,Comedy,Drama  350 min
# 4      Action,Adventure,Sci-Fi        0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1690 entries, 0 to 1689
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ID           1690 non-null   int64
#  1   Movie        1690 non-null   object
#  2   Year         1657 non-null   object
#  3   Genre        1683 non-null   object
#  4   RunTime      1690 non-null   object
#  5   Description  1690 non-null   object
#  6   IMDB_Score   1690 non-null   float64
# dtypes: float64(1), int64(1), object(5)
# memory usage: 92.5+ KB

# %%
df.groupby('Genre').sum().head(5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-44-a769e5a8aef8> in <cell line: 1>()
# ----> 1 df.groupby('Genre').sum().head(5)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/groupby.py in sum(self, numeric_only, min_count, engine, engine_kwargs)
#    3144             # _agg_general() returns. GH #31422
#    3145             with com.temp_setattr(self, "observed", True):
# -> 3146                 result = self._agg_general(
#    3147                     numeric_only=numeric_only,
#    3148                     min_count=min_count,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/groupby.py in _agg_general(self, numeric_only, min_count, alias, npfunc, **kwargs)
#    1904         **kwargs,
#    1905     ):
# -> 1906         result = self._cython_agg_general(
#    1907             how=alias,
#    1908             alt=npfunc,
#
# ...

# %%
import numpy as np

# %%
df = df.fillna(0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1690 entries, 0 to 1689
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ID           1690 non-null   int64
#  1   Movie        1690 non-null   object
#  2   Year         1690 non-null   object
#  3   Genre        1690 non-null   object
#  4   RunTime      1690 non-null   object
#  5   Description  1690 non-null   object
#  6   IMDB_Score   1690 non-null   float64
# dtypes: float64(1), int64(1), object(5)
# memory usage: 92.5+ KB

# %%
df['RunTime'] = df['RunTime'].str.replace(r'[a-zA-Z]','', regex=True)

# %%
df
# Out:
#         ID                              Movie         Year  \
# 0        0                           Eternals        -2021
# 1        1                               Loki     (2021– )
# 2        2  The Falcon and the Winter Soldier        -2021
# 3        3                        WandaVision        -2021
# 4        4            Spider-Man: No Way Home        -2021
# ...    ...                                ...          ...
# 1685  1685           DC's Legends of Tomorrow     (2016– )
# 1686  1686                          Supergirl  (2015–2021)
# 1687  1687                          Supergirl  (2015–2021)
# 1688  1688                          Supergirl  (2015–2021)
# 1689  1689                          Supergirl  (2015–2021)
#
#                          Genre RunTime  \
# 0       Action,Adventure,Drama       0
# 1     Action,Adventure,Fantasy       0
# 2       Action,Adventure,Drama     50
# 3          Action,Comedy,Drama    350
# 4      Action,Adventure,Sci-Fi       0
# ...

# %%
df['RunTime'] = df['RunTime'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1690 entries, 0 to 1689
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ID           1690 non-null   int64
#  1   Movie        1690 non-null   object
#  2   Year         1690 non-null   object
#  3   Genre        1690 non-null   object
#  4   RunTime      1690 non-null   int64
#  5   Description  1690 non-null   object
#  6   IMDB_Score   1690 non-null   float64
# dtypes: float64(1), int64(2), object(4)
# memory usage: 92.5+ KB

# %%
df_int = df.groupby('Genre').sum('RunTime')

df_int.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 91 entries, 0 to Talk-Show
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   ID          91 non-null     int64
#  1   RunTime     91 non-null     int64
#  2   IMDB_Score  91 non-null     float64
# dtypes: float64(1), int64(2)
# memory usage: 2.8+ KB

# %%
df_int
# Out:
#                             ID  RunTime  IMDB_Score
# Genre
# 0                         3619      120        17.4
# Action                     455        0         6.6
# Action,Adventure          1635      551        29.5
# Action,Adventure,Comedy  28064     1711       174.4
# Action,Adventure,Crime   36519     1483       252.1
# ...                        ...      ...         ...
# Short,Adventure,Sci-Fi     559       12         8.1
# Short,Comedy,Fantasy        63        4         8.1
# Short,Comedy,Music          49        4         8.1
# Short,Sci-Fi               176       29        13.5
# Talk-Show                 1531       82         0.0
#
# [91 rows x 3 columns]

# %%
df_int[df_int['ID'] == 455]
# Out:
#          ID  RunTime  IMDB_Score
# Genre
# Action  455        0         6.6
