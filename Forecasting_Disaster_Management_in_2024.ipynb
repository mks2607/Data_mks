# %% [markdown]
# <a href="https://colab.research.google.com/github/mks2607/Data_Scientist/blob/mks2607/Forecasting_Disaster_Management_in_2024.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("umeradnaan/prediction-of-disaster-management-in-2024")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 293k/293k [00:00<00:00, 38.9MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/umeradnaan/prediction-of-disaster-management-in-2024/versions/1

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/natural_disasters_2024.csv')

# %%
df
# Out:
#       Disaster_ID Disaster_Type   Location  Magnitude                 Date  \
# 0               1      Wildfire     Brazil   6.267393  2024-01-01 00:00:00
# 1               2     Hurricane  Indonesia   6.649358  2024-01-01 01:00:00
# 2               3       Tornado      China   9.724366  2024-01-01 02:00:00
# 3               4         Flood      India   1.702505  2024-01-01 03:00:00
# 4               5         Flood     Brazil   7.917748  2024-01-01 04:00:00
# ...           ...           ...        ...        ...                  ...
# 9995         9996     Hurricane      China   3.092801  2025-02-20 11:00:00
# 9996         9997       Tornado     Brazil   6.652682  2025-02-20 12:00:00
# 9997         9998    Earthquake  Indonesia   6.824656  2025-02-20 13:00:00
# 9998         9999         Flood        USA   6.381571  2025-02-20 14:00:00
# 9999        10000    Earthquake     Brazil   8.556928  2025-02-20 15:00:00
#
#       Fatalities  Economic_Loss($)
# ...

# %%
df.head()
# Out:
#    Disaster_ID Disaster_Type   Location  Magnitude                 Date  \
# 0            1      Wildfire     Brazil   6.267393  2024-01-01 00:00:00
# 1            2     Hurricane  Indonesia   6.649358  2024-01-01 01:00:00
# 2            3       Tornado      China   9.724366  2024-01-01 02:00:00
# 3            4         Flood      India   1.702505  2024-01-01 03:00:00
# 4            5         Flood     Brazil   7.917748  2024-01-01 04:00:00
#
#    Fatalities  Economic_Loss($)
# 0        9706      6.509790e+08
# 1        2233      5.538357e+08
# 2         478      6.910998e+07
# 3        2867      8.474880e+08
# 4         776      6.449297e+08

# %%
df.tail()
# Out:
#       Disaster_ID Disaster_Type   Location  Magnitude                 Date  \
# 9995         9996     Hurricane      China   3.092801  2025-02-20 11:00:00
# 9996         9997       Tornado     Brazil   6.652682  2025-02-20 12:00:00
# 9997         9998    Earthquake  Indonesia   6.824656  2025-02-20 13:00:00
# 9998         9999         Flood        USA   6.381571  2025-02-20 14:00:00
# 9999        10000    Earthquake     Brazil   8.556928  2025-02-20 15:00:00
#
#       Fatalities  Economic_Loss($)
# 9995        7837      1.067089e+07
# 9996        6288      1.414537e+08
# 9997         673      8.330828e+08
# 9998         323      9.502971e+08
# 9999        2620      3.732303e+08

# %%
df['Date'] = df['Date'].str.split(' ').str[0]

# %%
df
# Out:
#       Disaster_ID Disaster_Type   Location  Magnitude        Date  Fatalities  \
# 0               1      Wildfire     Brazil   6.267393  2024-01-01        9706
# 1               2     Hurricane  Indonesia   6.649358  2024-01-01        2233
# 2               3       Tornado      China   9.724366  2024-01-01         478
# 3               4         Flood      India   1.702505  2024-01-01        2867
# 4               5         Flood     Brazil   7.917748  2024-01-01         776
# ...           ...           ...        ...        ...         ...         ...
# 9995         9996     Hurricane      China   3.092801  2025-02-20        7837
# 9996         9997       Tornado     Brazil   6.652682  2025-02-20        6288
# 9997         9998    Earthquake  Indonesia   6.824656  2025-02-20         673
# 9998         9999         Flood        USA   6.381571  2025-02-20         323
# 9999        10000    Earthquake     Brazil   8.556928  2025-02-20        2620
#
#       Economic_Loss($)
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Disaster_ID       10000 non-null  int64
#  1   Disaster_Type     10000 non-null  object
#  2   Location          10000 non-null  object
#  3   Magnitude         10000 non-null  float64
#  4   Date              10000 non-null  object
#  5   Fatalities        10000 non-null  int64
#  6   Economic_Loss($)  10000 non-null  float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 547.0+ KB

# %%
import pandas as pd

df['Date'] = pd.to_datetime(df['Date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Disaster_ID       10000 non-null  int64
#  1   Disaster_Type     10000 non-null  object
#  2   Location          10000 non-null  object
#  3   Magnitude         10000 non-null  float64
#  4   Date              10000 non-null  datetime64[ns]
#  5   Fatalities        10000 non-null  int64
#  6   Economic_Loss($)  10000 non-null  float64
# dtypes: datetime64[ns](1), float64(2), int64(2), object(2)
# memory usage: 547.0+ KB

# %%
df.describe()
# Out:
#        Disaster_ID     Magnitude                        Date    Fatalities  \
# count  10000.00000  10000.000000                       10000  10000.000000
# mean    5000.50000      5.559173  2024-07-26 20:00:23.040000   4984.928900
# min        1.00000      1.000656         2024-01-01 00:00:00      0.000000
# 25%     2500.75000      3.263217         2024-04-14 00:00:00   2481.750000
# 50%     5000.50000      5.589578         2024-07-27 00:00:00   4947.000000
# 75%     7500.25000      7.829268         2024-11-08 00:00:00   7511.250000
# max    10000.00000      9.999671         2025-02-20 00:00:00   9999.000000
# std     2886.89568      2.619304                         NaN   2900.114029
#
#        Economic_Loss($)
# count      1.000000e+04
# mean       5.049752e+08
# min        1.036597e+06
# 25%        2.636352e+08
# 50%        5.078407e+08
# 75%        7.527256e+08
# max        9.998528e+08
# std        2.861325e+08

# %%
df.head(3)
# Out:
#    Disaster_ID Disaster_Type   Location  Magnitude       Date  Fatalities  \
# 0            1      Wildfire     Brazil   6.267393 2024-01-01        9706
# 1            2     Hurricane  Indonesia   6.649358 2024-01-01        2233
# 2            3       Tornado      China   9.724366 2024-01-01         478
#
#    Economic_Loss($)
# 0      6.509790e+08
# 1      5.538357e+08
# 2      6.910998e+07

# %%
df.loc[100]
# Out:
# Disaster_ID                         101
# Disaster_Type                     Flood
# Location                      Indonesia
# Magnitude                      5.050844
# Date                2024-01-05 00:00:00
# Fatalities                         8655
# Economic_Loss($)       798763257.175893
# Name: 100, dtype: object

# %%
df_Fatalities = df[['Location','Date','Magnitude','Fatalities']]

# %%
df_Fatalities
# Out:
#        Location       Date  Magnitude  Fatalities
# 0        Brazil 2024-01-01   6.267393        9706
# 1     Indonesia 2024-01-01   6.649358        2233
# 2         China 2024-01-01   9.724366         478
# 3         India 2024-01-01   1.702505        2867
# 4        Brazil 2024-01-01   7.917748         776
# ...         ...        ...        ...         ...
# 9995      China 2025-02-20   3.092801        7837
# 9996     Brazil 2025-02-20   6.652682        6288
# 9997  Indonesia 2025-02-20   6.824656         673
# 9998        USA 2025-02-20   6.381571         323
# 9999     Brazil 2025-02-20   8.556928        2620
#
# [10000 rows x 4 columns]
