# %% [markdown]
# <a href="https://colab.research.google.com/github/mks2607/Data_Scientist/blob/mks2607/Forecasting_Disaster_Management_in_2024.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("umeradnaan/prediction-of-disaster-management-in-2024")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 293k/293k [00:00<00:00, 36.3MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/umeradnaan/prediction-of-disaster-management-in-2024/versions/1

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/natural_disasters_2024.csv')

# %%
df
# Out:
#       Disaster_ID Disaster_Type   Location  Magnitude                 Date  \
# 0               1      Wildfire     Brazil   6.267393  2024-01-01 00:00:00
# 1               2     Hurricane  Indonesia   6.649358  2024-01-01 01:00:00
# 2               3       Tornado      China   9.724366  2024-01-01 02:00:00
# 3               4         Flood      India   1.702505  2024-01-01 03:00:00
# 4               5         Flood     Brazil   7.917748  2024-01-01 04:00:00
# ...           ...           ...        ...        ...                  ...
# 9995         9996     Hurricane      China   3.092801  2025-02-20 11:00:00
# 9996         9997       Tornado     Brazil   6.652682  2025-02-20 12:00:00
# 9997         9998    Earthquake  Indonesia   6.824656  2025-02-20 13:00:00
# 9998         9999         Flood        USA   6.381571  2025-02-20 14:00:00
# 9999        10000    Earthquake     Brazil   8.556928  2025-02-20 15:00:00
#
#       Fatalities  Economic_Loss($)
# ...

# %%
df.head()
# Out:
#    Disaster_ID Disaster_Type   Location  Magnitude                 Date  \
# 0            1      Wildfire     Brazil   6.267393  2024-01-01 00:00:00
# 1            2     Hurricane  Indonesia   6.649358  2024-01-01 01:00:00
# 2            3       Tornado      China   9.724366  2024-01-01 02:00:00
# 3            4         Flood      India   1.702505  2024-01-01 03:00:00
# 4            5         Flood     Brazil   7.917748  2024-01-01 04:00:00
#
#    Fatalities  Economic_Loss($)
# 0        9706      6.509790e+08
# 1        2233      5.538357e+08
# 2         478      6.910998e+07
# 3        2867      8.474880e+08
# 4         776      6.449297e+08

# %%
df.tail()
# Out:
#       Disaster_ID Disaster_Type   Location  Magnitude                 Date  \
# 9995         9996     Hurricane      China   3.092801  2025-02-20 11:00:00
# 9996         9997       Tornado     Brazil   6.652682  2025-02-20 12:00:00
# 9997         9998    Earthquake  Indonesia   6.824656  2025-02-20 13:00:00
# 9998         9999         Flood        USA   6.381571  2025-02-20 14:00:00
# 9999        10000    Earthquake     Brazil   8.556928  2025-02-20 15:00:00
#
#       Fatalities  Economic_Loss($)
# 9995        7837      1.067089e+07
# 9996        6288      1.414537e+08
# 9997         673      8.330828e+08
# 9998         323      9.502971e+08
# 9999        2620      3.732303e+08

# %%
df['Date'] = df['Date'].str.split(' ').str[0]

# %%
df
# Out:
#       Disaster_ID Disaster_Type   Location  Magnitude        Date  Fatalities  \
# 0               1      Wildfire     Brazil   6.267393  2024-01-01        9706
# 1               2     Hurricane  Indonesia   6.649358  2024-01-01        2233
# 2               3       Tornado      China   9.724366  2024-01-01         478
# 3               4         Flood      India   1.702505  2024-01-01        2867
# 4               5         Flood     Brazil   7.917748  2024-01-01         776
# ...           ...           ...        ...        ...         ...         ...
# 9995         9996     Hurricane      China   3.092801  2025-02-20        7837
# 9996         9997       Tornado     Brazil   6.652682  2025-02-20        6288
# 9997         9998    Earthquake  Indonesia   6.824656  2025-02-20         673
# 9998         9999         Flood        USA   6.381571  2025-02-20         323
# 9999        10000    Earthquake     Brazil   8.556928  2025-02-20        2620
#
#       Economic_Loss($)
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Disaster_ID       10000 non-null  int64
#  1   Disaster_Type     10000 non-null  object
#  2   Location          10000 non-null  object
#  3   Magnitude         10000 non-null  float64
#  4   Date              10000 non-null  object
#  5   Fatalities        10000 non-null  int64
#  6   Economic_Loss($)  10000 non-null  float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 547.0+ KB

# %%
import pandas as pd

df['Date'] = pd.to_datetime(df['Date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Disaster_ID       10000 non-null  int64
#  1   Disaster_Type     10000 non-null  object
#  2   Location          10000 non-null  object
#  3   Magnitude         10000 non-null  float64
#  4   Date              10000 non-null  datetime64[ns]
#  5   Fatalities        10000 non-null  int64
#  6   Economic_Loss($)  10000 non-null  float64
# dtypes: datetime64[ns](1), float64(2), int64(2), object(2)
# memory usage: 547.0+ KB

# %%
df.describe()
# Out:
#        Disaster_ID     Magnitude                        Date    Fatalities  \
# count  10000.00000  10000.000000                       10000  10000.000000
# mean    5000.50000      5.559173  2024-07-26 20:00:23.040000   4984.928900
# min        1.00000      1.000656         2024-01-01 00:00:00      0.000000
# 25%     2500.75000      3.263217         2024-04-14 00:00:00   2481.750000
# 50%     5000.50000      5.589578         2024-07-27 00:00:00   4947.000000
# 75%     7500.25000      7.829268         2024-11-08 00:00:00   7511.250000
# max    10000.00000      9.999671         2025-02-20 00:00:00   9999.000000
# std     2886.89568      2.619304                         NaN   2900.114029
#
#        Economic_Loss($)
# count      1.000000e+04
# mean       5.049752e+08
# min        1.036597e+06
# 25%        2.636352e+08
# 50%        5.078407e+08
# 75%        7.527256e+08
# max        9.998528e+08
# std        2.861325e+08

# %%
df.head(3)
# Out:
#    Disaster_ID Disaster_Type   Location  Magnitude       Date  Fatalities  \
# 0            1      Wildfire     Brazil   6.267393 2024-01-01        9706
# 1            2     Hurricane  Indonesia   6.649358 2024-01-01        2233
# 2            3       Tornado      China   9.724366 2024-01-01         478
#
#    Economic_Loss($)
# 0      6.509790e+08
# 1      5.538357e+08
# 2      6.910998e+07

# %%
df.loc[100]
# Out:
# Disaster_ID                         101
# Disaster_Type                     Flood
# Location                      Indonesia
# Magnitude                      5.050844
# Date                2024-01-05 00:00:00
# Fatalities                         8655
# Economic_Loss($)       798763257.175893
# Name: 100, dtype: object

# %%
df_Fatalities = df[['Location','Date','Magnitude','Fatalities']]

# %%
df_Fatalities
# Out:
#        Location       Date  Magnitude  Fatalities
# 0        Brazil 2024-01-01   6.267393        9706
# 1     Indonesia 2024-01-01   6.649358        2233
# 2         China 2024-01-01   9.724366         478
# 3         India 2024-01-01   1.702505        2867
# 4        Brazil 2024-01-01   7.917748         776
# ...         ...        ...        ...         ...
# 9995      China 2025-02-20   3.092801        7837
# 9996     Brazil 2025-02-20   6.652682        6288
# 9997  Indonesia 2025-02-20   6.824656         673
# 9998        USA 2025-02-20   6.381571         323
# 9999     Brazil 2025-02-20   8.556928        2620
#
# [10000 rows x 4 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Disaster_ID       10000 non-null  int64
#  1   Disaster_Type     10000 non-null  object
#  2   Location          10000 non-null  object
#  3   Magnitude         10000 non-null  float64
#  4   Date              10000 non-null  datetime64[ns]
#  5   Fatalities        10000 non-null  int64
#  6   Economic_Loss($)  10000 non-null  float64
# dtypes: datetime64[ns](1), float64(2), int64(2), object(2)
# memory usage: 547.0+ KB

# %%
df.head(3)
# Out:
#    Disaster_ID Disaster_Type   Location  Magnitude       Date  Fatalities  \
# 0            1      Wildfire     Brazil   6.267393 2024-01-01        9706
# 1            2     Hurricane  Indonesia   6.649358 2024-01-01        2233
# 2            3       Tornado      China   9.724366 2024-01-01         478
#
#    Economic_Loss($)
# 0      6.509790e+08
# 1      5.538357e+08
# 2      6.910998e+07

# %%
columns_list = df.columns.tolist()
print(columns_list)

for index, column in enumerate(df.columns):
    print(index,column)
# Out:
# ['Disaster_ID', 'Disaster_Type', 'Location', 'Magnitude', 'Date', 'Fatalities', 'Economic_Loss($)']
# 0 Disaster_ID
# 1 Disaster_Type
# 2 Location
# 3 Magnitude
# 4 Date
# 5 Fatalities
# 6 Economic_Loss($)

# %%
print(df.columns)
# Out:
# Index(['Disaster_ID', 'Disaster_Type', 'Location', 'Magnitude', 'Date',
#        'Fatalities', 'Economic_Loss($)'],
#       dtype='object')

# %%
df.iloc[:500]
# Out:
#      Disaster_ID Disaster_Type   Location  Magnitude       Date  Fatalities  \
# 0              1      Wildfire     Brazil   6.267393 2024-01-01        9706
# 1              2     Hurricane  Indonesia   6.649358 2024-01-01        2233
# 2              3       Tornado      China   9.724366 2024-01-01         478
# 3              4         Flood      India   1.702505 2024-01-01        2867
# 4              5         Flood     Brazil   7.917748 2024-01-01         776
# ..           ...           ...        ...        ...        ...         ...
# 495          496      Wildfire     Brazil   6.627654 2024-01-21         299
# 496          497     Hurricane  Indonesia   4.898351 2024-01-21        6210
# 497          498         Flood      China   3.790339 2024-01-21        8309
# 498          499    Earthquake        USA   8.743218 2024-01-21         174
# 499          500    Earthquake     Brazil   6.565349 2024-01-21        5980
#
#      Economic_Loss($)
# 0        6.509790e+08
# ...

# %%
from matplotlib import pyplot as plt
_df_2['Fatalities'].plot(kind='hist', bins=20, title='Fatalities')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
_df_1['Magnitude'].plot(kind='hist', bins=20, title='Magnitude')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
df
# Out:
#       Disaster_ID Disaster_Type   Location  Magnitude       Date  Fatalities  \
# 0               1      Wildfire     Brazil   6.267393 2024-01-01        9706
# 1               2     Hurricane  Indonesia   6.649358 2024-01-01        2233
# 2               3       Tornado      China   9.724366 2024-01-01         478
# 3               4         Flood      India   1.702505 2024-01-01        2867
# 4               5         Flood     Brazil   7.917748 2024-01-01         776
# ...           ...           ...        ...        ...        ...         ...
# 9995         9996     Hurricane      China   3.092801 2025-02-20        7837
# 9996         9997       Tornado     Brazil   6.652682 2025-02-20        6288
# 9997         9998    Earthquake  Indonesia   6.824656 2025-02-20         673
# 9998         9999         Flood        USA   6.381571 2025-02-20         323
# 9999        10000    Earthquake     Brazil   8.556928 2025-02-20        2620
#
#       Economic_Loss($)
# ...

# %%
df_USA = df[df['Location'] == 'USA']

# %%
df_USA
# Out:
#       Disaster_ID Disaster_Type Location  Magnitude       Date  Fatalities  \
# 11             12         Flood      USA   9.465754 2024-01-01         439
# 12             13    Earthquake      USA   6.143754 2024-01-01         206
# 21             22     Hurricane      USA   5.672029 2024-01-01         593
# 23             24     Hurricane      USA   3.619608 2024-01-01        3763
# 24             25      Wildfire      USA   2.211183 2024-01-02        9780
# ...           ...           ...      ...        ...        ...         ...
# 9966         9967     Hurricane      USA   4.525027 2025-02-19        7625
# 9972         9973       Tornado      USA   9.242234 2025-02-19         927
# 9986         9987     Hurricane      USA   2.553486 2025-02-20        7365
# 9993         9994      Wildfire      USA   7.559203 2025-02-20        9213
# 9998         9999         Flood      USA   6.381571 2025-02-20         323
#
#       Economic_Loss($)
# 11        3.507375e+08
# ...

# %%
from google.colab import sheets
sheet = sheets.InteractiveSheet(df=df_USA)
# Out:
# https://docs.google.com/spreadsheets/d/19XKkgdbplpn4acareoc3E1Kenn7Zen7Gl7nm6WxLwy4#gid=0
# /usr/local/lib/python3.10/dist-packages/google/colab/sheets.py:31: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   return frame.applymap(_clean_val).replace({np.nan: None})
#         <iframe
#             width="100%"
#             height="600"
#             src="https://docs.google.com/spreadsheets/d/19XKkgdbplpn4acareoc3E1Kenn7Zen7Gl7nm6WxLwy4#gid=0/edit?rm=embedded?usp=sharing?widget=true&amp;headers=false"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
df_cleaned = df.dropna()

# %%
df_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Disaster_ID       10000 non-null  int64
#  1   Disaster_Type     10000 non-null  object
#  2   Location          10000 non-null  object
#  3   Magnitude         10000 non-null  float64
#  4   Date              10000 non-null  datetime64[ns]
#  5   Fatalities        10000 non-null  int64
#  6   Economic_Loss($)  10000 non-null  float64
# dtypes: datetime64[ns](1), float64(2), int64(2), object(2)
# memory usage: 547.0+ KB

# %%
print(df['Location'].unique())
# Out:
# ['Brazil' 'Indonesia' 'China' 'India' 'USA' 'Japan']

# %% [markdown]
# Создаем отдельные таблицы по каждой стране

# %%
df_USA = df[(df['Location'] == 'USA') & (df['Disaster_Type'] == 'Tornado')]
df_Brazil = df[(df['Location'] == 'Brazil') & (df['Disaster_Type'] == 'Tornado')]
df_Indonesia = df[df['Location'] == 'Indonesia']
df_China = df[df['Location'] == 'China']
df_India = df[df['Location'] == 'India']
df_Japan = df[df['Location'] == 'Japan']

# %%
df_China
# Out:
#       Disaster_ID Disaster_Type Location  Magnitude       Date  Fatalities  \
# 2               3       Tornado    China   9.724366 2024-01-01         478
# 5               6       Tornado    China   2.717113 2024-01-01        3534
# 7               8    Earthquake    China   2.652747 2024-01-01        2261
# 13             14    Earthquake    China   8.948563 2024-01-01        2176
# 25             26         Flood    China   2.003896 2024-01-02        2415
# ...           ...           ...      ...        ...        ...         ...
# 9975         9976         Flood    China   8.118341 2025-02-19        9757
# 9979         9980       Tornado    China   7.233430 2025-02-19        8483
# 9983         9984       Tornado    China   3.095616 2025-02-19        9679
# 9990         9991    Earthquake    China   9.098895 2025-02-20        6532
# 9995         9996     Hurricane    China   3.092801 2025-02-20        7837
#
#       Economic_Loss($)
# 2         6.910998e+07
# ...

# %%
# Условие с разбивкой по логическим операторам с несколькими значениями
filtered_combined = df[(df['Fatalities'] > 5000) | (df['Disaster_Type'] == 'Tornado')]

# %%
filtered_combined
# Out:
#       Disaster_ID Disaster_Type Location  Magnitude       Date  Fatalities  \
# 0               1      Wildfire   Brazil   6.267393 2024-01-01        9706
# 2               3       Tornado    China   9.724366 2024-01-01         478
# 5               6       Tornado    China   2.717113 2024-01-01        3534
# 6               7     Hurricane    India   6.491891 2024-01-01        8220
# 8               9         Flood   Brazil   8.157574 2024-01-01        5016
# ...           ...           ...      ...        ...        ...         ...
# 9991         9992    Earthquake   Brazil   4.849218 2025-02-20        8668
# 9992         9993       Tornado   Brazil   5.510024 2025-02-20        8781
# 9993         9994      Wildfire      USA   7.559203 2025-02-20        9213
# 9995         9996     Hurricane    China   3.092801 2025-02-20        7837
# 9996         9997       Tornado   Brazil   6.652682 2025-02-20        6288
#
#       Economic_Loss($)
# 0         6.509790e+08
# ...

# %%
df_USA
# Out:
#       Disaster_ID Disaster_Type Location  Magnitude       Date  Fatalities  \
# 107           108       Tornado      USA   6.112114 2024-01-05         356
# 125           126       Tornado      USA   4.336671 2024-01-06        2242
# 126           127       Tornado      USA   2.896444 2024-01-06        4093
# 141           142       Tornado      USA   8.183347 2024-01-06        2697
# 152           153       Tornado      USA   8.955034 2024-01-07         891
# ...           ...           ...      ...        ...        ...         ...
# 9801         9802       Tornado      USA   8.281852 2025-02-12        9331
# 9808         9809       Tornado      USA   4.782504 2025-02-12        8126
# 9815         9816       Tornado      USA   7.144056 2025-02-12        1545
# 9964         9965       Tornado      USA   6.560611 2025-02-19         618
# 9972         9973       Tornado      USA   9.242234 2025-02-19         927
#
#       Economic_Loss($)
# 107       6.940742e+08
# ...

# %%
df_Brazil
# Out:
#       Disaster_ID Disaster_Type Location  Magnitude       Date  Fatalities  \
# 38             39       Tornado   Brazil   5.486964 2024-01-02        1175
# 44             45       Tornado   Brazil   6.696510 2024-01-02        1458
# 76             77       Tornado   Brazil   1.419720 2024-01-04        3540
# 80             81       Tornado   Brazil   5.407126 2024-01-04        5890
# 98             99       Tornado   Brazil   2.021851 2024-01-05        9214
# ...           ...           ...      ...        ...        ...         ...
# 9961         9962       Tornado   Brazil   3.838280 2025-02-19        6744
# 9967         9968       Tornado   Brazil   8.206793 2025-02-19        1599
# 9971         9972       Tornado   Brazil   5.331164 2025-02-19        1449
# 9992         9993       Tornado   Brazil   5.510024 2025-02-20        8781
# 9996         9997       Tornado   Brazil   6.652682 2025-02-20        6288
#
#       Economic_Loss($)
# 38        7.094717e+08
# ...

# %%
df_Brazil_TOP = (df_Brazil.sort_values(by='Fatalities', ascending=False))

# %%
df_Brazil_TOP = df_Brazil_TOP[df_Brazil_TOP['Fatalities'] > 9000]
df_Brazil_TOP.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 37 entries, 788 to 1150
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Disaster_ID       37 non-null     int64
#  1   Disaster_Type     37 non-null     object
#  2   Location          37 non-null     object
#  3   Magnitude         37 non-null     float64
#  4   Date              37 non-null     datetime64[ns]
#  5   Fatalities        37 non-null     int64
#  6   Economic_Loss($)  37 non-null     float64
# dtypes: datetime64[ns](1), float64(2), int64(2), object(2)
# memory usage: 2.3+ KB

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_Brazil_TOP
# Out:
#       Disaster_ID Disaster_Type Location  Magnitude       Date  Fatalities  \
# 788           789       Tornado   Brazil   1.327141 2024-02-02        9987
# 1663         1664       Tornado   Brazil   1.045712 2024-03-10        9935
# 6264         6265       Tornado   Brazil   1.238325 2024-09-18        9935
# 1208         1209       Tornado   Brazil   7.015508 2024-02-20        9930
# 6911         6912       Tornado   Brazil   8.128158 2024-10-14        9904
# 725           726       Tornado   Brazil   2.495411 2024-01-31        9883
# 6579         6580       Tornado   Brazil   7.624118 2024-10-01        9826
# 1612         1613       Tornado   Brazil   2.727559 2024-03-08        9773
# 4545         4546       Tornado   Brazil   2.171631 2024-07-08        9754
# 6417         6418       Tornado   Brazil   2.928931 2024-09-24        9749
# 8091         8092       Tornado   Brazil   9.678796 2024-12-03        9705
# ...

# %%
from matplotlib import pyplot as plt
df_Brazil_TOP['Disaster_ID'].plot(kind='hist', bins=20, title='Disaster_ID')
plt.gca().spines[['top', 'right',]].set_visible(False)
