# %% [markdown]
# <a href="https://colab.research.google.com/github/mks2607/Data_Scientist/blob/mks2607/SVO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Изучение - потери оборудования

# %%
import pandas as pd
import matplotlib
import seaborn as sns

# %% [markdown]
# импортируем таблицу.
# df - основную таблицу можно называть всегда так , что бы было понятно , что бы заниматся - ИДС(исследовательский анализ данных)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv("/content/russia_losses_equipment.csv")
df
# Out:
#            date  day  aircraft  helicopter  tank    APC  field artillery  \
# 0    2024-08-25  914       367         328  8547  16631            17396
# 1    2024-08-24  913       367         328  8542  16620            17349
# 2    2024-08-23  912       367         328  8533  16599            17307
# 3    2024-08-22  911       367         328  8529  16567            17262
# 4    2024-08-21  910       367         328  8522  16542            17216
# ..          ...  ...       ...         ...   ...    ...              ...
# 908  2022-03-01    6        29          29   198    846               77
# 909  2022-02-28    5        29          29   150    816               74
# 910  2022-02-27    4        27          26   150    706               50
# 911  2022-02-26    3        27          26   146    706               49
# 912  2022-02-25    2        10           7    80    516               49
#
#       MRL  military auto  fuel tank  drone  naval ship  anti-aircraft warfare  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 913 entries, 0 to 912
# Data columns (total 19 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   date                       913 non-null    object
#  1   day                        913 non-null    int64
#  2   aircraft                   913 non-null    int64
#  3   helicopter                 913 non-null    int64
#  4   tank                       913 non-null    int64
#  5   APC                        913 non-null    int64
#  6   field artillery            913 non-null    int64
#  7   MRL                        913 non-null    int64
#  8   military auto              65 non-null     float64
#  9   fuel tank                  65 non-null     float64
#  10  drone                      913 non-null    int64
#  11  naval ship                 913 non-null    int64
#  12  anti-aircraft warfare      913 non-null    int64
# ...

# %%
print(df['helicopter'])
# Out:
# 0      328
# 1      328
# 2      328
# 3      328
# 4      328
#       ...
# 908     29
# 909     29
# 910     26
# 911     26
# 912      7
# Name: helicopter, Length: 913, dtype: int64

# %%
df.head()
# Out:
#          date  day  aircraft  helicopter  tank    APC  field artillery   MRL  \
# 0  2024-08-25  914       367         328  8547  16631            17396  1171
# 1  2024-08-24  913       367         328  8542  16620            17349  1169
# 2  2024-08-23  912       367         328  8533  16599            17307  1167
# 3  2024-08-22  911       367         328  8529  16567            17262  1166
# 4  2024-08-21  910       367         328  8522  16542            17216  1166
#
#    military auto  fuel tank  drone  naval ship  anti-aircraft warfare  \
# 0            NaN        NaN  14095          28                    936
# 1            NaN        NaN  14064          28                    935
# 2            NaN        NaN  14025          28                    932
# 3            NaN        NaN  13998          28                    931
# 4            NaN        NaN  13902          28                    928
#
#    special equipment  mobile SRBM system greatest losses direction  \
# ...

# %%
df.groupby(['greatest losses direction','date']).mean()
# Out:
#                                                      day  aircraft  \
# greatest losses direction              date
# Avdiivka                               2022-05-09   75.0     199.0
#                                        2022-05-10   76.0     199.0
#                                        2022-05-26   92.0     206.0
#                                        2022-05-27   93.0     206.0
#                                        2022-07-11  138.0     217.0
# ...                                                  ...       ...
# Sloviansk, Kryvyi Rih and Zaporizhzhia 2022-05-18   84.0     202.0
#                                        2022-05-19   85.0     203.0
# Zaporizhzhia                           2022-05-30   96.0     207.0
#                                        2022-06-04  101.0     210.0
# Zaporizhzhia and Izyum                 2022-04-28   64.0     187.0
#
#                                                    helicopter    tank     APC  \
# ...

# %%
print(df['aircraft'].max()) #максимальное и минимальное количество самолетов
print(df['aircraft'].min())
# Out:
# 367
# 10

# %%
print(df['helicopter'].max()) #максимальное и минимальное количество вертолетов
print(df['helicopter'].min())
# Out:
# 328
# 7

# %%
print(df['field artillery'].max()) #максимальное и минимальное количество артилерии
print(df['field artillery'].min())
# Out:
# 17396
# 49

# %%
print(df['APC'].max()) #максимальное и минимальное количество БТР
print(df['APC'].min())
# Out:
# 16631
# 516

# %%
print(df['drone'].max()) #максимальное и минимальное количество дронов
print(df['drone'].min())
print(df['drone'].mean())
# Out:
# 14095
# 0
# 4295.673603504929

# %%
df.count()
# Out:
# date                         913
# day                          913
# aircraft                     913
# helicopter                   913
# tank                         913
# APC                          913
# field artillery              913
# MRL                          913
# military auto                 65
# fuel tank                     65
# drone                        913
# naval ship                   913
# anti-aircraft warfare        913
# special equipment            894
# mobile SRBM system            36
# greatest losses direction    203
# vehicles and fuel tanks      848
# cruise missiles              848
# submarines                   347
# dtype: int64

# %%
df['drone'].value_counts()
# Out:
# drone
# 7       7
# 3       6
# 1537    4
# 2339    4
# 1872    3
#        ..
# 5554    1
# 5495    1
# 5488    1
# 5468    1
# 0       1
# Name: count, Length: 834, dtype: int64
