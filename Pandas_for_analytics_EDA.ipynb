# %% [markdown]
# <a href="https://colab.research.google.com/github/mks2607/Data_mks/blob/mks2607/Pandas_for_analytics_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
aug_test  = pd.read_csv('/content/aug_test.csv')
aug_train = pd.read_csv('/content/aug_train.csv')
sample_submission = pd.read_csv('/content/sample_submission.csv')

# %%
aug_test
# Out:
#       enrollee_id      city  city_development_index  gender  \
# 0           32403   city_41                   0.827    Male
# 1            9858  city_103                   0.920  Female
# 2           31806   city_21                   0.624    Male
# 3           27385   city_13                   0.827    Male
# 4           27724  city_103                   0.920    Male
# ...           ...       ...                     ...     ...
# 2124         1289  city_103                   0.920    Male
# 2125          195  city_136                   0.897    Male
# 2126        31762  city_100                   0.887    Male
# 2127         7873  city_102                   0.804    Male
# 2128        12215  city_102                   0.804    Male
#
#           relevent_experience enrolled_university education_level  \
# 0     Has relevent experience    Full time course        Graduate
# 1     Has relevent experience       no_enrollment        Graduate
# ...

# %%
aug_train
# Out:
#        enrollee_id      city  city_development_index gender  \
# 0             8949  city_103                   0.920   Male
# 1            29725   city_40                   0.776   Male
# 2            11561   city_21                   0.624    NaN
# 3            33241  city_115                   0.789    NaN
# 4              666  city_162                   0.767   Male
# ...            ...       ...                     ...    ...
# 19153         7386  city_173                   0.878   Male
# 19154        31398  city_103                   0.920   Male
# 19155        24576  city_103                   0.920   Male
# 19156         5756   city_65                   0.802   Male
# 19157        23834   city_67                   0.855    NaN
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 1       No relevent experience       no_enrollment        Graduate
# ...

# %%
sample_submission
# Out:
#       enrollee_id  target
# 0           32403     0.5
# 1            9858     0.5
# 2           31806     0.5
# 3           27385     0.5
# 4           27724     0.5
# ...           ...     ...
# 2124         1289     0.5
# 2125          195     0.5
# 2126        31762     0.5
# 2127         7873     0.5
# 2128        12215     0.5
#
# [2129 rows x 2 columns]

# %%
word = 'ab\'c'
word
# Out:
# "ab'c"

# %% [markdown]
# #Списки

# %%
nums = [1,2,3]

# %%
nums
# Out:
# [1, 2, 3]

# %%
nums[0]
# Out:
# 1

# %%
nums[0] * 2
# Out:
# 2

# %%
for num in range(len(nums)):
  print(nums[num] * 2)
# Out:
# 2
# 4
# 6

# %%
list(range(100,1,-10))
# Out:
# [100, 90, 80, 70, 60, 50, 40, 30, 20, 10]

# %%
for num in nums:
  print(num)


for num in nums:
  print(num * 2)
# Out:
# 1
# 2
# 3
# 2
# 4
# 6

# %%
for i,num in enumerate(nums):
  print(i,num)
# Out:
# 0 1
# 1 2
# 2 3

# %%
tuple_1 = (1,2,3) # не изменяемый

# %%
nums.append(4)
nums
# Out:
# [1, 2, 3, 4, 4]

# %%
tuple_1.append(4)
tuple_1 # AttributeError: 'tuple' object has no attribute 'append'
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-51-d560945df338> in <cell line: 1>()
# ----> 1 tuple_1.append(4)
#       2 tuple_1
#
# AttributeError: 'tuple' object has no attribute 'append'

# %% [markdown]
# #Слайсиинг

# %%
nums
# Out:
# [1, 2, 3, 4, 4]

# %%
nums[0:3]
# Out:
# [1, 2, 3]

# %%
nums[2:]
# Out:
# [3, 4, 4]

# %%
nums[-1]
# Out:
# 4

# %%
nums[:-1]
# Out:
# [1, 2, 3, 4]

# %%
nums[0::3]
# Out:
# [1, 4]

# %%
nums[::-1]
# Out:
# [4, 4, 3, 2, 1]

# %%
word[::-1]
# Out:
# "c'ba"

# %% [markdown]
# # if then

# %%
if 2>1:
  print("Условие выполнено")
else:
  print('Не выполнено')
# Out:
# Условие выполнено

# %%
num = 4

# %%
if num > 10:
  print('Число больше 10')
elif num > 5:
  print('Число больше 5')
else:
  print('Число меньше 5')
# Out:
# Число меньше 5

# %% [markdown]
# # List comprehensions(понимание)

# %%
nums = [1,2,3,4,5,6,7,8]

# %%
new = []
for num in nums:
  new.append(num * 2)

# %%
new
# Out:
# [2, 4, 6, 8, 10, 12, 14, 16]

# %%
[num for num in nums]
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8]

# %%
[num*2 for num in nums]
# Out:
# [2, 4, 6, 8, 10, 12, 14, 16]

# %%
[num*3 for num in nums]
# Out:
# [3, 6, 9, 12, 15, 18, 21, 24]

# %%
new = []
for num in nums:
  if num>2:
    new.append(num * 2)

new
# Out:
# [6, 8, 10, 12, 14, 16]

# %%
[num*2 for num in nums if num > 2]
# Out:
# [6, 8, 10, 12, 14, 16]

# %%
new = []
for num in nums:
  if num>2:
    new.append(True)
  else:
    new.append(False)

new
# Out:
# [False, False, True, True, True, True, True, True]

# %%
[True if num > 2 else False for num in nums]
# Out:
# [False, False, True, True, True, True, True, True]

# %%
[1 for i in range(3)]
# Out:
# [1, 1, 1]

# %%
[1 for _ in range(3)]
# Out:
# [1, 1, 1]

# %%
[[1 for i in range(3)] for _ in range(3)]
# Out:
# [[1, 1, 1], [1, 1, 1], [1, 1, 1]]

# %% [markdown]
# # True False

# %%
print(True)
print(False)
# Out:
# True
# False

# %%
2>1
# Out:
# True

# %%
flag = True

# %%
True == True
# Out:
# True

# %%
flag = 1

if flag:
  print('закончить')
# Out:
# закончить

# %%
flag = 0

if flag:
  print('закончить')

# %% [markdown]
# # Функции

# %%
nums = [1,2,3,4,5,6]

# %%
new = []
for num in nums:
  new.append(num *2)

new
# Out:
# [2, 4, 6, 8, 10, 12, 14, 16]

# %%
nums_1 = [12,23,35,654]

# %%
new = []
for num in nums_1:
  new.append(num * 2)

new
# Out:
# [24, 46, 70, 1308]

# %%
def mult_2(nums):
  new = []
  for num in nums:
    new.append(num * 2)
  return new

# %%
mult_2(nums)
# Out:
# [2, 4, 6, 8, 10, 12, 14, 16]

# %%
mult_2([2,2,2,2])
# Out:
# [4, 4, 4, 4]

# %%
mult_2([3,3,3,3,3,3,3,3,3])
# Out:
# [6, 6, 6, 6, 6, 6, 6, 6, 6]

# %%
mult_2([10,22,33,100])
# Out:
# [20, 44, 66, 200]

# %%
def mult(nums,k):
  new = []
  for num in nums:
    new.append(num * k)
  return new

# %%
mult([1,2,3],100)
# Out:
# [100, 200, 300]

# %% [markdown]
# # Словари (hash таблицы)

# %%
arr = [('a',11),('b',122),('c',312)]

# %%
arr
# Out:
# [('a', 11), ('b', 122), ('c', 312)]

# %%
for el in arr:
  print(el)
# Out:
# ('a', 11)
# ('b', 122)
# ('c', 312)

# %%
for el in arr:
  if el[0] == 'c':
    print(el)
# Out:
# ('c', 312)

# %%
#поиск в словаре не зависит от размера словаря

dict_arr = {'a':11,'b':122,'c':312}

# %%
dict_arr['c']
# Out:
# 312

# %%
var = 'a'

# %%
if var == 'a':
  print(11)
elif var == 'b':
  print(1234)
elif var == 'c':
  print(312)
# Out:
# 11

# %%
ddict_arr[var]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-129-e822c5fd09e2> in <cell line: 1>()
# ----> 1 ddict_arr[var]
#
# NameError: name 'ddict_arr' is not defined

# %%
dict_arr.get(var,'не найдено')
# Out:
# 11

# %%
dict_arr.get('c','не найдено')
# Out:
# 312

# %%
dict_arr.get('ab','не найдено')
# Out:
# 'не найдено'

# %% [markdown]
# # Сет

# %%
{1,2,3,4} #всегда уникальные значения
# Out:
# {1, 2, 3, 4}

# %%
nums = [1,2,2,3,2,3,45,36567,67853,3,2,4354,5]
nums
# Out:
# [1, 2, 2, 3, 2, 3, 45, 36567, 67853, 3, 2, 4354, 5]

# %%
nums_set = set(nums)
nums_set
# Out:
# {1, 2, 3, 5, 45, 4354, 36567, 67853}

# %%
4 in nums_set
# Out:
# False

# %%
4 in nums
# Out:
# False

# %%
s1 = {1,2,3}

# %%
s2 = {2,3}

# %%
s1 - s2
# Out:
# {1}

# %%
s2 - s1
# Out:
# set()

# %%
s1.intersection(s2)
# Out:
# {2, 3}

# %%
s1.union(s2) # уникальные элементы двух сетов
# Out:
# {1, 2, 3}

# %% [markdown]
# # Конкатинация - сцепка

# %%
'kir'+'-'+'ill'
# Out:
# 'kir-ill'

# %%
'kir'+'ill'
# Out:
# 'kirill'

# %%
[1] + [2,2]
# Out:
# [1, 2, 2]

# %%
[1] * 5
# Out:
# [1, 1, 1, 1, 1]

# %%
[1] * 5 + [0]*3
# Out:
# [1, 1, 1, 1, 1, 0, 0, 0]

# %%
'kir'*3 + 'ill'
# Out:
# 'kirkirkirill'

# %% [markdown]
# # While

# %%
nums = [1,2,3,4,5,6]

# %%
nums.pop()
# Out:
# 6

# %%
nums
# Out:
# [1, 2, 3, 4, 5]

# %%
while len(nums) > 2:
  nums.pop()

# %%
nums
# Out:
# [1, 2]

# %%
nums_1 = [1,2,3] * 100

# %%
len(nums_1)
# Out:
# 300

# %%
while len(nums_1) > 2:
  nums_1.pop()

# %%
len(nums_1)
# Out:
# 2

# %% [markdown]
# # Классы

# %%
it_spec = [('Jon','DE',150),('Carl','DA',120),('Kir','DS',300)]

# %%
it_spec
# Out:
# [('Jon', 'DE', 150), ('Carl', 'DA', 120), ('Kir', 'DS', 300)]

# %%
class IT_SPEC:
  def __init__(self,name,speciality,salary):
    self.name = name
    self.speciality = speciality
    self.salary = salary
  def tell_about_youself(self):
    return f'Hi! My name in {self.name}. I\'m a {self.speciality}. My salary is {self.salary}'

# %%
jon = IT_SPEC('Jon','DE',150)
jon

# %%
jon.name
# Out:
# 'Jon'

# %%
jon.salary
# Out:
# 150

# %%
jon.speciality
# Out:
# 'DE'

# %%
carl = IT_SPEC('Carl','DA',120)

# %%
print(carl.name)
print(carl.salary)
print(carl.speciality)
# Out:
# Carl
# 120
# DA

# %%
jon.tell_about_youself()
# Out:
# "Hi! My name in Jon. I'm a DE. My salary is 150"

# %%
kir = DataScantist('Kir','DS',300)
kir

# %%
class DataScantist(IT_SPEC):

  def __init__(salf,name,salary):
    super().__init__(name,'DS',salary)

  def ml(self,data):
    return 'profit for company(and myself)'

# %%
kir = DataScantist('Kir','DS',300)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-218-402c2bd39ef9> in <cell line: 1>()
# ----> 1 kir = DataScantist('Kir','DS',300)
#
# TypeError: DataScantist.__init__() takes 3 positional arguments but 4 were given

# %%
kir = DataScantist('Kir',300)

# %%
kir.tell_about_youself()
# Out:
# "Hi! My name in Kir. I'm a DS. My salary is 300"

# %%
kir.tell_about_youself()
# Out:
# "Hi! My name in Kir. I'm a DS. My salary is 300"

# %%
kir.ml([1,2,232,-1])
# Out:
# 'profit for company(and myself)'

# %% [markdown]
# # Pandas

# %% [markdown]
# aug_test  = pd.read_csv('/content/aug_test.csv')
# aug_train = pd.read_csv('/content/aug_train.csv')
# sample_submission = pd.read_csv('/content/sample_submission.csv')

# %%
aug_train
# Out:
#        enrollee_id      city  city_development_index gender  \
# 0             8949  city_103                   0.920   Male
# 1            29725   city_40                   0.776   Male
# 2            11561   city_21                   0.624    NaN
# 3            33241  city_115                   0.789    NaN
# 4              666  city_162                   0.767   Male
# ...            ...       ...                     ...    ...
# 19153         7386  city_173                   0.878   Male
# 19154        31398  city_103                   0.920   Male
# 19155        24576  city_103                   0.920   Male
# 19156         5756   city_65                   0.802   Male
# 19157        23834   city_67                   0.855    NaN
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 1       No relevent experience       no_enrollment        Graduate
# ...

# %% [markdown]
# # Горячие клавиши

# %% [markdown]
# command + m - включение режима "горячие клавиши"
#
# *   d - удалить ячейку
# *   b - вставить ячейку после текущей
# *   a - вставить ячейку перед текущей
# *   m - вставить текстовую ячейку
# *   y - изменить текстовую ячейку на код

# %%
df = pd.read_csv('/content/aug_train.csv',encoding='cp1251')
df
# Out:
#        enrollee_id      city  city_development_index gender  \
# 0             8949  city_103                   0.920   Male
# 1            29725   city_40                   0.776   Male
# 2            11561   city_21                   0.624    NaN
# 3            33241  city_115                   0.789    NaN
# 4              666  city_162                   0.767   Male
# ...            ...       ...                     ...    ...
# 19153         7386  city_173                   0.878   Male
# 19154        31398  city_103                   0.920   Male
# 19155        24576  city_103                   0.920   Male
# 19156         5756   city_65                   0.802   Male
# 19157        23834   city_67                   0.855    NaN
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 1       No relevent experience       no_enrollment        Graduate
# ...

# %%
from google.colab import sheets
sheet = sheets.InteractiveSheet(df=df)
# Out:
# https://docs.google.com/spreadsheets/d/1VNeSx6JO_eGKQWJoIlN08ysSZkfcCWEEhENiYLb5xQE#gid=0
#         <iframe
#             width="100%"
#             height="600"
#             src="https://docs.google.com/spreadsheets/d/1VNeSx6JO_eGKQWJoIlN08ysSZkfcCWEEhENiYLb5xQE#gid=0/edit?rm=embedded?usp=sharing?widget=true&amp;headers=false"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
df.head(3)
# Out:
#    enrollee_id      city  city_development_index gender  \
# 0         8949  city_103                   0.920   Male
# 1        29725   city_40                   0.776   Male
# 2        11561   city_21                   0.624    NaN
#
#        relevent_experience enrolled_university education_level  \
# 0  Has relevent experience       no_enrollment        Graduate
# 1   No relevent experience       no_enrollment        Graduate
# 2   No relevent experience    Full time course        Graduate
#
#   major_discipline experience company_size company_type last_new_job  \
# 0             STEM        >20          NaN          NaN            1
# 1             STEM         15        50-99      Pvt Ltd           >4
# 2             STEM          5          NaN          NaN        never
#
#    training_hours  target
# 0              36     1.0
# 1              47     0.0
# 2              83     0.0

# %%
df['city']
# Out:
# 0        city_103
# 1         city_40
# 2         city_21
# 3        city_115
# 4        city_162
#            ...
# 19153    city_173
# 19154    city_103
# 19155    city_103
# 19156     city_65
# 19157     city_67
# Name: city, Length: 19158, dtype: object

# %%
df[['city','city_development_index']]
# Out:
#            city  city_development_index
# 0      city_103                   0.920
# 1       city_40                   0.776
# 2       city_21                   0.624
# 3      city_115                   0.789
# 4      city_162                   0.767
# ...         ...                     ...
# 19153  city_173                   0.878
# 19154  city_103                   0.920
# 19155  city_103                   0.920
# 19156   city_65                   0.802
# 19157   city_67                   0.855
#
# [19158 rows x 2 columns]

# %%
len(df)
# Out:
# 19158

# %%
df.drop('city',axis=1) #inplace - окончательное удаление.Сейчас не используется - делается просто перезапись
# Out:
#        enrollee_id  city_development_index gender      relevent_experience  \
# 0             8949                   0.920   Male  Has relevent experience
# 1            29725                   0.776   Male   No relevent experience
# 2            11561                   0.624    NaN   No relevent experience
# 3            33241                   0.789    NaN   No relevent experience
# 4              666                   0.767   Male  Has relevent experience
# ...            ...                     ...    ...                      ...
# 19153         7386                   0.878   Male   No relevent experience
# 19154        31398                   0.920   Male  Has relevent experience
# 19155        24576                   0.920   Male  Has relevent experience
# 19156         5756                   0.802   Male  Has relevent experience
# 19157        23834                   0.855    NaN   No relevent experience
#
# ...

# %%
df
# Out:
#        enrollee_id      city  city_development_index gender  \
# 0             8949  city_103                   0.920   Male
# 1            29725   city_40                   0.776   Male
# 2            11561   city_21                   0.624    NaN
# 3            33241  city_115                   0.789    NaN
# 4              666  city_162                   0.767   Male
# ...            ...       ...                     ...    ...
# 19153         7386  city_173                   0.878   Male
# 19154        31398  city_103                   0.920   Male
# 19155        24576  city_103                   0.920   Male
# 19156         5756   city_65                   0.802   Male
# 19157        23834   city_67                   0.855    NaN
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 1       No relevent experience       no_enrollment        Graduate
# ...

# %%
df.columns
# Out:
# Index(['enrollee_id', 'city', 'city_development_index', 'gender',
#        'relevent_experience', 'enrolled_university', 'education_level',
#        'major_discipline', 'experience', 'company_size', 'company_type',
#        'last_new_job', 'training_hours', 'target'],
#       dtype='object')

# %%
df_1 = df[['enrollee_id', 'city', 'city_development_index', 'gender',
       'relevent_experience', 'enrolled_university', 'education_level',
       'major_discipline']]

df_1
# Out:
#        enrollee_id      city  city_development_index gender  \
# 0             8949  city_103                   0.920   Male
# 1            29725   city_40                   0.776   Male
# 2            11561   city_21                   0.624    NaN
# 3            33241  city_115                   0.789    NaN
# 4              666  city_162                   0.767   Male
# ...            ...       ...                     ...    ...
# 19153         7386  city_173                   0.878   Male
# 19154        31398  city_103                   0.920   Male
# 19155        24576  city_103                   0.920   Male
# 19156         5756   city_65                   0.802   Male
# 19157        23834   city_67                   0.855    NaN
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 1       No relevent experience       no_enrollment        Graduate
# ...

# %%
df['new_col'] = 1

# %%
df
# Out:
#        enrollee_id      city  city_development_index gender  \
# 0             8949  city_103                   0.920   Male
# 1            29725   city_40                   0.776   Male
# 2            11561   city_21                   0.624    NaN
# 3            33241  city_115                   0.789    NaN
# 4              666  city_162                   0.767   Male
# ...            ...       ...                     ...    ...
# 19153         7386  city_173                   0.878   Male
# 19154        31398  city_103                   0.920   Male
# 19155        24576  city_103                   0.920   Male
# 19156         5756   city_65                   0.802   Male
# 19157        23834   city_67                   0.855    NaN
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 1       No relevent experience       no_enrollment        Graduate
# ...

# %%
df['new_cal2'] = df['city_development_index']/3

# %%
df
# Out:
#        enrollee_id      city  city_development_index gender  \
# 0             8949  city_103                   0.920   Male
# 1            29725   city_40                   0.776   Male
# 2            11561   city_21                   0.624    NaN
# 3            33241  city_115                   0.789    NaN
# 4              666  city_162                   0.767   Male
# ...            ...       ...                     ...    ...
# 19153         7386  city_173                   0.878   Male
# 19154        31398  city_103                   0.920   Male
# 19155        24576  city_103                   0.920   Male
# 19156         5756   city_65                   0.802   Male
# 19157        23834   city_67                   0.855    NaN
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 1       No relevent experience       no_enrollment        Graduate
# ...

# %%
df['new_cal3'] = df['city_development_index']/df['training_hours']
df
# Out:
#        enrollee_id      city  city_development_index gender  \
# 0             8949  city_103                   0.920   Male
# 1            29725   city_40                   0.776   Male
# 2            11561   city_21                   0.624    NaN
# 3            33241  city_115                   0.789    NaN
# 4              666  city_162                   0.767   Male
# ...            ...       ...                     ...    ...
# 19153         7386  city_173                   0.878   Male
# 19154        31398  city_103                   0.920   Male
# 19155        24576  city_103                   0.920   Male
# 19156         5756   city_65                   0.802   Male
# 19157        23834   city_67                   0.855    NaN
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 1       No relevent experience       no_enrollment        Graduate
# ...

# %%
df.assign(new_cal3 = 99)
# Out:
#        enrollee_id      city  city_development_index gender  \
# 0             8949  city_103                   0.920   Male
# 1            29725   city_40                   0.776   Male
# 2            11561   city_21                   0.624    NaN
# 3            33241  city_115                   0.789    NaN
# 4              666  city_162                   0.767   Male
# ...            ...       ...                     ...    ...
# 19153         7386  city_173                   0.878   Male
# 19154        31398  city_103                   0.920   Male
# 19155        24576  city_103                   0.920   Male
# 19156         5756   city_65                   0.802   Male
# 19157        23834   city_67                   0.855    NaN
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 1       No relevent experience       no_enrollment        Graduate
# ...

# %% [markdown]
# # Фильтрация

# %%
df[df['city'] == 'city_40']
# Out:
#        enrollee_id     city  city_development_index gender  \
# 1            29725  city_40                   0.776   Male
# 23            7041  city_40                   0.776   Male
# 363          28229  city_40                   0.776   Male
# 461          18620  city_40                   0.776   Male
# 827           1783  city_40                   0.776   Male
# ...            ...      ...                     ...    ...
# 18032          982  city_40                   0.776    NaN
# 18061        11208  city_40                   0.776   Male
# 18191          157  city_40                   0.776   Male
# 18650        26348  city_40                   0.776   Male
# 19142        13750  city_40                   0.776   Male
#
#            relevent_experience enrolled_university education_level  \
# 1       No relevent experience       no_enrollment        Graduate
# 23     Has relevent experience       no_enrollment        Graduate
# ...

# %%
df.query('city == "city_40"')
# Out:
#        enrollee_id     city  city_development_index gender  \
# 1            29725  city_40                   0.776   Male
# 23            7041  city_40                   0.776   Male
# 363          28229  city_40                   0.776   Male
# 461          18620  city_40                   0.776   Male
# 827           1783  city_40                   0.776   Male
# ...            ...      ...                     ...    ...
# 18032          982  city_40                   0.776    NaN
# 18061        11208  city_40                   0.776   Male
# 18191          157  city_40                   0.776   Male
# 18650        26348  city_40                   0.776   Male
# 19142        13750  city_40                   0.776   Male
#
#            relevent_experience enrolled_university education_level  \
# 1       No relevent experience       no_enrollment        Graduate
# 23     Has relevent experience       no_enrollment        Graduate
# ...

# %%
df[(df['city'] == 'city_40')&(df['gender'] == 'Male')]
# Out:
#        enrollee_id     city  city_development_index gender  \
# 1            29725  city_40                   0.776   Male
# 23            7041  city_40                   0.776   Male
# 363          28229  city_40                   0.776   Male
# 461          18620  city_40                   0.776   Male
# 827           1783  city_40                   0.776   Male
# 998          29671  city_40                   0.776   Male
# 2916         21646  city_40                   0.776   Male
# 3636         10085  city_40                   0.776   Male
# 4251          2603  city_40                   0.776   Male
# 4346          4051  city_40                   0.776   Male
# 4526         11840  city_40                   0.776   Male
# 4588          7010  city_40                   0.776   Male
# 5156          7556  city_40                   0.776   Male
# 6330          5389  city_40                   0.776   Male
# 6483           484  city_40                   0.776   Male
# ...

# %%
df.query('city == "city_40" and gender == "Male"') # другой способ фильтрации(но суть та же самая)
# Out:
#        enrollee_id     city  city_development_index gender  \
# 1            29725  city_40                   0.776   Male
# 23            7041  city_40                   0.776   Male
# 363          28229  city_40                   0.776   Male
# 461          18620  city_40                   0.776   Male
# 827           1783  city_40                   0.776   Male
# 998          29671  city_40                   0.776   Male
# 2916         21646  city_40                   0.776   Male
# 3636         10085  city_40                   0.776   Male
# 4251          2603  city_40                   0.776   Male
# 4346          4051  city_40                   0.776   Male
# 4526         11840  city_40                   0.776   Male
# 4588          7010  city_40                   0.776   Male
# 5156          7556  city_40                   0.776   Male
# 6330          5389  city_40                   0.776   Male
# 6483           484  city_40                   0.776   Male
# ...

# %%
city_40_female = df.query('city == "city_40" and gender == "Male"')
city_40_female
# Out:
#        enrollee_id     city  city_development_index gender  \
# 1            29725  city_40                   0.776   Male
# 23            7041  city_40                   0.776   Male
# 363          28229  city_40                   0.776   Male
# 461          18620  city_40                   0.776   Male
# 827           1783  city_40                   0.776   Male
# 998          29671  city_40                   0.776   Male
# 2916         21646  city_40                   0.776   Male
# 3636         10085  city_40                   0.776   Male
# 4251          2603  city_40                   0.776   Male
# 4346          4051  city_40                   0.776   Male
# 4526         11840  city_40                   0.776   Male
# 4588          7010  city_40                   0.776   Male
# 5156          7556  city_40                   0.776   Male
# 6330          5389  city_40                   0.776   Male
# 6483           484  city_40                   0.776   Male
# ...

# %%
city_40_female['new_col3'] = 1 # в новой переменной данные не создаются новые данные. они оставляют только ссылку на исходные данные - поэтому надо ставить copy()
# Out:
# <ipython-input-262-9cce0806e025>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   city_40_female['new_col3'] = 1

# %%
city_40_female = df.query('city == "city_40" and gender == "Male"').copy()
city_40_female['new_col4'] = 2

# %%
city_40_female
# Out:
#        enrollee_id     city  city_development_index gender  \
# 1            29725  city_40                   0.776   Male
# 23            7041  city_40                   0.776   Male
# 363          28229  city_40                   0.776   Male
# 461          18620  city_40                   0.776   Male
# 827           1783  city_40                   0.776   Male
# 998          29671  city_40                   0.776   Male
# 2916         21646  city_40                   0.776   Male
# 3636         10085  city_40                   0.776   Male
# 4251          2603  city_40                   0.776   Male
# 4346          4051  city_40                   0.776   Male
# 4526         11840  city_40                   0.776   Male
# 4588          7010  city_40                   0.776   Male
# 5156          7556  city_40                   0.776   Male
# 6330          5389  city_40                   0.776   Male
# 6483           484  city_40                   0.776   Male
# ...

# %% [markdown]
# # Пропуски

# %%
df.isna().mean().sort_values(ascending=False) # пользоватся долями что бы не было путаницы во время анализа
# Out:
# company_type              0.320493
# company_size              0.309949
# gender                    0.235306
# major_discipline          0.146832
# education_level           0.024011
# last_new_job              0.022080
# enrolled_university       0.020148
# experience                0.003393
# training_hours            0.000000
# new_cal2                  0.000000
# new_col                   0.000000
# target                    0.000000
# enrollee_id               0.000000
# city                      0.000000
# relevent_experience       0.000000
# city_development_index    0.000000
# new_cal3                  0.000000
# dtype: float64

# %%
# пропуски заполнять только при необходимости, например при разработки модели данных.
# при анализе лучше не заполнять, что бы получать реальную картину

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19158 entries, 0 to 19157
# Data columns (total 17 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   enrollee_id             19158 non-null  int64
#  1   city                    19158 non-null  object
#  2   city_development_index  19158 non-null  float64
#  3   gender                  14650 non-null  object
#  4   relevent_experience     19158 non-null  object
#  5   enrolled_university     18772 non-null  object
#  6   education_level         18698 non-null  object
#  7   major_discipline        16345 non-null  object
#  8   experience              19093 non-null  object
#  9   company_size            13220 non-null  object
#  10  company_type            13018 non-null  object
#  11  last_new_job            18735 non-null  object
#  12  training_hours          19158 non-null  int64
#  13  target                  19158 non-null  float64
# ...

# %%
df.dtypes
# Out:
# enrollee_id                 int64
# city                       object
# city_development_index    float64
# gender                     object
# relevent_experience        object
# enrolled_university        object
# education_level            object
# major_discipline           object
# experience                 object
# company_size               object
# company_type               object
# last_new_job               object
# training_hours              int64
# target                    float64
# new_col                     int64
# new_cal2                  float64
# new_cal3                  float64
# dtype: object

# %% [markdown]
# # Типы переменных

# %%
df.head()
# Out:
#    enrollee_id      city  city_development_index gender  \
# 0         8949  city_103                   0.920   Male
# 1        29725   city_40                   0.776   Male
# 2        11561   city_21                   0.624    NaN
# 3        33241  city_115                   0.789    NaN
# 4          666  city_162                   0.767   Male
#
#        relevent_experience enrolled_university education_level  \
# 0  Has relevent experience       no_enrollment        Graduate
# 1   No relevent experience       no_enrollment        Graduate
# 2   No relevent experience    Full time course        Graduate
# 3   No relevent experience                 NaN        Graduate
# 4  Has relevent experience       no_enrollment         Masters
#
#   major_discipline experience company_size    company_type last_new_job  \
# 0             STEM        >20          NaN             NaN            1
# 1             STEM         15        50-99         Pvt Ltd           >4
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.style.use('dark_background') # применим темную тему

# %%
df['city_development_index'].hist()
# Out:
# <Axes: >

# %%
df.describe()
# Out:
#         enrollee_id  city_development_index  training_hours        target  \
# count  19158.000000            19158.000000    19158.000000  19158.000000
# mean   16875.358179                0.828848       65.366896      0.249348
# std     9616.292592                0.123362       60.058462      0.432647
# min        1.000000                0.448000        1.000000      0.000000
# 25%     8554.250000                0.740000       23.000000      0.000000
# 50%    16982.500000                0.903000       47.000000      0.000000
# 75%    25169.750000                0.920000       88.000000      0.000000
# max    33380.000000                0.949000      336.000000      1.000000
#
#        new_col      new_cal2      new_cal3
# count  19158.0  19158.000000  19158.000000
# mean       1.0      0.276283      0.033439
# std        0.0      0.041121      0.051378
# min        1.0      0.149333      0.001516
# 25%        1.0      0.246667      0.009246
# ...

# %%
df['gender'].value_counts(dropna=False) # dropna - показываете количество пропусков
# Out:
# gender
# Male      13221
# NaN        4508
# Female     1238
# Other       191
# Name: count, dtype: int64

# %% [markdown]
# # Фильтрация по квантилям

# %% [markdown]
# квантиль == процентиль

# %%
q = df['city_development_index'].quantile(0.25)

# %%
q
# Out:
# 0.74

# %%
q_5 = df['city_development_index'].quantile(0.05)
q_6 = df['city_development_index'].quantile(0.95)

# %%
df['city_development_index'].hist()
# Out:
# <Axes: >

# %%
df[df['city_development_index'] >= q_5]['city_development_index'].hist() # убрали 5% - выбросы которые исключаем
# Out:
# <Axes: >

# %%
df[df['city_development_index'].between(q_5,q_6)]['city_development_index'].hist() # между 5 и 95%
# Out:
# <Axes: >

# %% [markdown]
# # Сводники, статистика

# %%
df.head()
# Out:
#    enrollee_id      city  city_development_index gender  \
# 0         8949  city_103                   0.920   Male
# 1        29725   city_40                   0.776   Male
# 2        11561   city_21                   0.624    NaN
# 3        33241  city_115                   0.789    NaN
# 4          666  city_162                   0.767   Male
#
#        relevent_experience enrolled_university education_level  \
# 0  Has relevent experience       no_enrollment        Graduate
# 1   No relevent experience       no_enrollment        Graduate
# 2   No relevent experience    Full time course        Graduate
# 3   No relevent experience                 NaN        Graduate
# 4  Has relevent experience       no_enrollment         Masters
#
#   major_discipline experience company_size    company_type last_new_job  \
# 0             STEM        >20          NaN             NaN            1
# 1             STEM         15        50-99         Pvt Ltd           >4
# ...

# %%
len(df)
# Out:
# 19158

# %%
df['target'].mean()
# Out:
# 0.24934753105752167

# %%
t = df.groupby('gender',dropna=False)['target'].agg(['count','mean'])

# %%
t
# Out:
#         count      mean
# gender
# Female   1238  0.263328
# Male    13221  0.227819
# Other     191  0.261780
# NaN      4508  0.308119

# %%
t['count'].sum() # контрольная сумма что бы данные не пропадали
# Out:
# 19158

# %%
t_1 = df.groupby('education_level',dropna=False)['target'].agg(['count','mean'])

# %%
t_1
# Out:
#                  count      mean
# education_level
# Graduate         11598  0.279790
# High School       2017  0.195340
# Masters           4361  0.214400
# Phd                414  0.140097
# Primary School     308  0.133117
# NaN                460  0.226087

# %%
df.groupby('education_level',dropna=False)['target'].mean().plot(kind='bar')
# Out:
# <Axes: xlabel='education_level'>

# %% [markdown]
# # Сводные таб для непрерывных переменных

# %%
df['city_development_index_group'] = pd.cut(df['city_development_index'],5) # разбивает данные на группы

# %%
df.groupby('city_development_index_group',dropna=False)['target'].agg(['count','mean'])
# Out:
# <ipython-input-310-59a18033b821>:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby('city_development_index_group',dropna=False)['target'].agg(['count','mean'])
#                               count      mean
# city_development_index_group
# (0.447, 0.548]                  178  0.578652
# (0.548, 0.648]                 3297  0.582651
# (0.648, 0.749]                 1529  0.273381
# (0.749, 0.849]                 1949  0.194459
# (0.849, 0.949]                12205  0.160262

# %%
df['city_development_index'].hist()
# Out:
# <Axes: >

# %%
df['city_development_index_group_q'] = pd.qcut(df['city_development_index'],5,duplicates='drop') # разбивает данные на равные группы

# %%
t = df.groupby('city_development_index_group_q',dropna=False)['target'].agg(['count','mean'])
# Out:
# <ipython-input-323-3723cef91dd1>:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   t = df.groupby('city_development_index_group_q',dropna=False)['target'].agg(['count','mean'])

# %%
t
# Out:
#                                 count      mean
# city_development_index_group_q
# (0.447, 0.691]                   3869  0.550530
# (0.691, 0.878]                   3827  0.206428
# (0.878, 0.92]                    8925  0.178375
# (0.92, 0.949]                    2537  0.104454

# %%
t['count'].sum()
# Out:
# 19158

# %%
t['mean'].plot()
# Out:
# <Axes: xlabel='city_development_index_group_q'>

# %%
df['city_development_index_group_custom'] = pd.cut(df['city_development_index'],[-float('inf'),0,0.1,0.2,0.5,float('inf')]) # сами задаем интервалы
# -float('inf')  - задает интервал до бесконечности - т.е. включает все значения

# %%
df.groupby('city_development_index_group_custom',dropna=False)['target'].agg(['count','mean'])
# Out:
# <ipython-input-333-1487f34e90cf>:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby('city_development_index_group_custom',dropna=False)['target'].agg(['count','mean'])
#                                      count      mean
# city_development_index_group_custom
# (-inf, 0.0]                              0       NaN
# (0.0, 0.1]                               0       NaN
# (0.1, 0.2]                               0       NaN
# (0.2, 0.5]                              63  0.587302
# (0.5, inf]                           19095  0.248233

# %%
t_1
# Out:
#                  count      mean
# education_level
# Graduate         11598  0.279790
# High School       2017  0.195340
# Masters           4361  0.214400
# Phd                414  0.140097
# Primary School     308  0.133117
# NaN                460  0.226087

# %%
# в пандаске строки циклом лучше не перебирать

def education_group(x):
  if x in ['High School','Primary School']:
    return 'School'
  if x in ['Masters','Phd']:
    return 'Masters_and_phd'
  return x

# %%
df['new_educatinal_level'] = df['education_level'].apply(education_group) # оозначает - применить эту функцию к этому столбцу

# %%
df.groupby('new_educatinal_level',dropna=False)['target'].agg(['count','mean'])
# Out:
#                       count      mean
# new_educatinal_level
# Graduate              11598  0.279790
# Masters_and_phd        4775  0.207958
# School                 2325  0.187097
# NaN                     460  0.226087

# %%
df['education_level'].replace('Primary School','School') # другой способ что бы перезаписать столбцы
# Out:
# 0           Graduate
# 1           Graduate
# 2           Graduate
# 3           Graduate
# 4            Masters
#             ...
# 19153       Graduate
# 19154       Graduate
# 19155       Graduate
# 19156    High School
# 19157         School
# Name: education_level, Length: 19158, dtype: object

# %%
d = {'Primary School':'School'} # др способ

# %%
df['education_level'].map(d)
# Out:
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
#           ...
# 19153       NaN
# 19154       NaN
# 19155       NaN
# 19156       NaN
# 19157    School
# Name: education_level, Length: 19158, dtype: object

# %% [markdown]
# # Функция с несколькими столбцами

# %%
df
# Out:
#        enrollee_id      city  city_development_index gender  \
# 0             8949  city_103                   0.920   Male
# 1            29725   city_40                   0.776   Male
# 2            11561   city_21                   0.624    NaN
# 3            33241  city_115                   0.789    NaN
# 4              666  city_162                   0.767   Male
# ...            ...       ...                     ...    ...
# 19153         7386  city_173                   0.878   Male
# 19154        31398  city_103                   0.920   Male
# 19155        24576  city_103                   0.920   Male
# 19156         5756   city_65                   0.802   Male
# 19157        23834   city_67                   0.855    NaN
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 1       No relevent experience       no_enrollment        Graduate
# ...

# %%
def new_training_hours(row):
  if row['education_level'] == 'Phd':
    return row['training_hours'] + 1000
  return row['training_hours']

# %%
df['new_training_hours'] = df.apply(new_training_hours,axis = 1)

# %%
df[df['education_level']== 'Pnd']
# Out:
# Empty DataFrame
# Columns: [enrollee_id, city, city_development_index, gender, relevent_experience, enrolled_university, education_level, major_discipline, experience, company_size, company_type, last_new_job, training_hours, target, new_col, new_cal2, new_cal3, city_development_index_group, city_development_index_group_q, city_development_index_group_custom, new_educatinal_level, new_training_hours]
# Index: []
#
# [0 rows x 22 columns]

# %%
df
# Out:
#        enrollee_id      city  city_development_index gender  \
# 0             8949  city_103                   0.920   Male
# 1            29725   city_40                   0.776   Male
# 2            11561   city_21                   0.624    NaN
# 3            33241  city_115                   0.789    NaN
# 4              666  city_162                   0.767   Male
# ...            ...       ...                     ...    ...
# 19153         7386  city_173                   0.878   Male
# 19154        31398  city_103                   0.920   Male
# 19155        24576  city_103                   0.920   Male
# 19156         5756   city_65                   0.802   Male
# 19157        23834   city_67                   0.855    NaN
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 1       No relevent experience       no_enrollment        Graduate
# ...

# %% [markdown]
# # Pivit Table

# %%
df.groupby('education_level',dropna=False)['target'].agg(['count','mean'])
# Out:
#                  count      mean
# education_level
# Graduate         11598  0.279790
# High School       2017  0.195340
# Masters           4361  0.214400
# Phd                414  0.140097
# Primary School     308  0.133117
# NaN                460  0.226087

# %%
df.pivot_table(index='education_level',values='target', aggfunc=['count','mean'])
# Out:
#                  count      mean
#                 target    target
# education_level
# Graduate         11598  0.279790
# High School       2017  0.195340
# Masters           4361  0.214400
# Phd                414  0.140097
# Primary School     308  0.133117

# %%
df['new_educatinal_level'] = df['new_educatinal_level'].fillna('no_info')

# %%
t = df.pivot_table(index='new_educatinal_level',values='target',aggfunc=['count','mean'])

# %%
t
# Out:
#                       count      mean
#                      target    target
# new_educatinal_level
# Graduate              11598  0.279790
# Masters_and_phd        4775  0.207958
# School                 2325  0.187097
# no_info                 460  0.226087

# %%
t.reset_index()
# Out:
#   new_educatinal_level  count      mean
#                        target    target
# 0             Graduate  11598  0.279790
# 1      Masters_and_phd   4775  0.207958
# 2               School   2325  0.187097
# 3              no_info    460  0.226087

# %%
t.columns = [' '.join(col).strip() for col in t.columns.values] # убирает мультистолбцы взял со stackoverflow

# %%
t = t.reset_index()

# %%
t
# Out:
#   new_educatinal_level  count target  mean target
# 0             Graduate         11598     0.279790
# 1      Masters_and_phd          4775     0.207958
# 2               School          2325     0.187097
# 3              no_info           460     0.226087

# %%
df.pivot_table(index='new_educatinal_level',columns='gender',values='target',aggfunc=['count','mean'])
# Out:
#                       count                  mean
# gender               Female  Male Other    Female      Male     Other
# new_educatinal_level
# Graduate                773  8144   112  0.279431  0.257122  0.330357
# Masters_and_phd         386  3237    31  0.233161  0.186284  0.096774
# School                   71  1598    39  0.267606  0.171464  0.205128
# no_info                   8   242     9  0.125000  0.169421  0.222222

# %%
df.groupby(['education_level','gender'],dropna=False)['target'].agg(['count','mean'])
# Out:
#                         count      mean
# education_level gender
# Graduate        Female    773  0.279431
#                 Male     8144  0.257122
#                 Other     112  0.330357
#                 NaN      2569  0.349552
# High School     Female     67  0.268657
#                 Male     1395  0.182796
#                 Other      33  0.181818
#                 NaN       522  0.220307
# Masters         Female    339  0.247788
#                 Male     2957  0.191410
#                 Other      27  0.074074
#                 NaN      1038  0.272640
# Phd             Female     47  0.127660
#                 Male      280  0.132143
#                 Other       4  0.250000
#                 NaN        83  0.168675
# Primary School  Female      4  0.250000
#                 Male      203  0.093596
#                 Other       6  0.333333
#                 NaN        95  0.200000
# NaN             Female      8  0.125000
#                 Male      242  0.169421
# ...

# %%
t_1 = df.groupby('education_level',dropna=False)[['target','city_development_index']].agg(['count','mean']).reset_index()

# %%
t_1
# Out:
#   education_level target           city_development_index
#                    count      mean                  count      mean
# 0        Graduate  11598  0.279790                  11598  0.823731
# 1     High School   2017  0.195340                   2017  0.833890
# 2         Masters   4361  0.214400                   4361  0.835947
# 3             Phd    414  0.140097                    414  0.883070
# 4  Primary School    308  0.133117                    308  0.850419
# 5             NaN    460  0.226087                    460  0.805207

# %% [markdown]
# # Heatmap (условное форматирование)

# %%
df['gender'] = df['gender'].fillna('no_info')

# %%
t = df.pivot_table(index='new_educatinal_level',columns='gender',values='target',aggfunc=['mean'])

# %%
t
# Out:
#                           mean
# gender                  Female      Male     Other   no_info
# new_educatinal_level
# Graduate              0.279431  0.257122  0.330357  0.349552
# Masters_and_phd       0.233161  0.186284  0.096774  0.264942
# School                0.267606  0.171464  0.205128  0.217180
# no_info               0.125000  0.169421  0.222222  0.298507

# %%
import seaborn as sns

# %%
sns.heatmap(t)
# Out:
# <Axes: xlabel='None-gender', ylabel='new_educatinal_level'>

# %%
df.pivot_table(index='new_educatinal_level',columns='gender',values='target',aggfunc=['count'])
# Out:
#                       count
# gender               Female  Male Other no_info
# new_educatinal_level
# Graduate                773  8144   112    2569
# Masters_and_phd         386  3237    31    1121
# School                   71  1598    39     617
# no_info                   8   242     9     201

# %% [markdown]
# # Корреляция и phik

# %%
df
# Out:
#        enrollee_id      city  city_development_index   gender  \
# 0             8949  city_103                   0.920     Male
# 1            29725   city_40                   0.776     Male
# 2            11561   city_21                   0.624  no_info
# 3            33241  city_115                   0.789  no_info
# 4              666  city_162                   0.767     Male
# ...            ...       ...                     ...      ...
# 19153         7386  city_173                   0.878     Male
# 19154        31398  city_103                   0.920     Male
# 19155        24576  city_103                   0.920     Male
# 19156         5756   city_65                   0.802     Male
# 19157        23834   city_67                   0.855  no_info
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 1       No relevent experience       no_enrollment        Graduate
# ...

# %%
sns.heatmap(df[['city_development_index','training_hours','target']].corr())
# Out:
# <Axes: >

# %%
pip install phik
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 686.1/686.1 kB 8.5 MB/s eta 0:00:00
# ...

# %%
import phik
from phik.report import plot_correlation_matrix
from phik import report

# %%
phik_overview = df.phik_matrix()
# Out:
# interval columns not set, guessing: ['enrollee_id', 'city_development_index', 'training_hours', 'target', 'new_col', 'new_cal2', 'new_cal3', 'new_training_hours']
# /usr/local/lib/python3.10/dist-packages/phik/data_quality.py:72: UserWarning: Not enough unique value for variable new_col for analysis 1. Dropping this column
#   warnings.warn(

# %%
phik_overview # считаются связи между категориальными переменными
# Out:
#                                      enrollee_id      city  \
# enrollee_id                             1.000000  0.214019
# city                                    0.214019  1.000000
# city_development_index                  0.125181  1.000000
# gender                                  0.125045  0.235773
# relevent_experience                     0.073145  0.152621
# enrolled_university                     0.051188  0.376293
# education_level                         0.076123  0.363706
# major_discipline                        0.030968  0.178508
# experience                              0.086949  0.346552
# company_size                            0.032956  0.249869
# company_type                            0.022543  0.224174
# last_new_job                            0.045252  0.240315
# training_hours                          0.021517  0.075165
# target                                  0.067472  0.477283
# new_cal2                                0.125181  1.000000
# ...

# %%
sns.heatmap(phik_overview)
# Out:
# <Axes: >

# %%
phik_overview['target'].sort_values(ascending=False) # нелинейные связи
# Out:
# target                                 1.000000
# city_development_index_group_q         0.523691
# city_development_index                 0.482287
# new_cal2                               0.482287
# city                                   0.477283
# city_development_index_group           0.302403
# experience                             0.238725
# relevent_experience                    0.199859
# new_educatinal_level                   0.132478
# gender                                 0.116653
# last_new_job                           0.114708
# enrolled_university                    0.093803
# education_level                        0.075999
# company_size                           0.071953
# enrollee_id                            0.067472
# company_type                           0.066792
# new_training_hours                     0.054314
# city_development_index_group_custom    0.035805
# major_discipline                       0.029200
# training_hours                         0.026849
# ...

# %% [markdown]
# # Проверка связей

# %%
df['city_development_index_group_q']
# Out:
# 0         (0.878, 0.92]
# 1        (0.691, 0.878]
# 2        (0.447, 0.691]
# 3        (0.691, 0.878]
# 4        (0.691, 0.878]
#               ...
# 19153    (0.691, 0.878]
# 19154     (0.878, 0.92]
# 19155     (0.878, 0.92]
# 19156    (0.691, 0.878]
# 19157    (0.691, 0.878]
# Name: city_development_index_group_q, Length: 19158, dtype: category
# Categories (4, interval[float64, right]): [(0.447, 0.691] < (0.691, 0.878] < (0.878, 0.92] <
#                                            (0.92, 0.949]]

# %%
df.groupby('city_development_index_group_q')['target'].agg(['count','mean'])
# Out:
# <ipython-input-401-645196e9793a>:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby('city_development_index_group_q')['target'].agg(['count','mean'])
#                                 count      mean
# city_development_index_group_q
# (0.447, 0.691]                   3869  0.550530
# (0.691, 0.878]                   3827  0.206428
# (0.878, 0.92]                    8925  0.178375
# (0.92, 0.949]                    2537  0.104454

# %%
t = df.groupby('city')['target'].agg(['count','mean'])

# %%
t.sort_values('count',ascending=False).head(10)['mean'].plot(kind='bar')
# Out:
# <Axes: xlabel='city'>

# %% [markdown]
# # Искуственные данные

# %%
t = pd.DataFrame({'cil1':[1,2,3,float('nan')],
                  'col2':['a','b','c','d'],
                  'cil3':[1,2,3,float('nan')],})

# %%
t
# Out:
#    cil1 col2  cil3
# 0   1.0    a   1.0
# 1   2.0    b   2.0
# 2   3.0    c   3.0
# 3   NaN    d   NaN

# %% [markdown]
# # Визуализация

# %%
df['city_development_index'].hist()
# Out:
# <Axes: >

# %%
df['gender'].value_counts().hist() # пропуски не видны
# Out:
# <Axes: >

# %%
df['gender'].value_counts(dropna=False).plot(kind='bar') # с пропусками
# Out:
# <Axes: xlabel='gender'>

# %% [markdown]
# # Skatter - исследует взаимосвязь между точками

# %%
t = pd.DataFrame({'x':[1,2,3],'y':[1,2,3]})

# %%
t.plot(x='x',y='y',kind = 'scatter')
# Out:
# <Axes: xlabel='x', ylabel='y'>

# %%
df
# Out:
#        enrollee_id      city  city_development_index   gender  \
# 0             8949  city_103                   0.920     Male
# 1            29725   city_40                   0.776     Male
# 2            11561   city_21                   0.624  no_info
# 3            33241  city_115                   0.789  no_info
# 4              666  city_162                   0.767     Male
# ...            ...       ...                     ...      ...
# 19153         7386  city_173                   0.878     Male
# 19154        31398  city_103                   0.920     Male
# 19155        24576  city_103                   0.920     Male
# 19156         5756   city_65                   0.802     Male
# 19157        23834   city_67                   0.855  no_info
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 1       No relevent experience       no_enrollment        Graduate
# ...

# %%
df.plot(x ='city_development_index',y = 'new_training_hours',kind = 'scatter',alpha = 0.05)
# Out:
# <Axes: xlabel='city_development_index', ylabel='new_training_hours'>

# %% [markdown]
# это основные виды визуализации которые используются

# %% [markdown]
# # Join

# %%
df
# Out:
#        enrollee_id      city  city_development_index   gender  \
# 0             8949  city_103                   0.920     Male
# 1            29725   city_40                   0.776     Male
# 2            11561   city_21                   0.624  no_info
# 3            33241  city_115                   0.789  no_info
# 4              666  city_162                   0.767     Male
# ...            ...       ...                     ...      ...
# 19153         7386  city_173                   0.878     Male
# 19154        31398  city_103                   0.920     Male
# 19155        24576  city_103                   0.920     Male
# 19156         5756   city_65                   0.802     Male
# 19157        23834   city_67                   0.855  no_info
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 1       No relevent experience       no_enrollment        Graduate
# ...

# %%
age = df[['enrollee_id']].copy()

# %%
age['age'] = 30

# %%
df = df.merge(age,how='left', on='enrollee_id')

# %%
df
# Out:
#        enrollee_id      city  city_development_index   gender  \
# 0             8949  city_103                   0.920     Male
# 1            29725   city_40                   0.776     Male
# 2            11561   city_21                   0.624  no_info
# 3            33241  city_115                   0.789  no_info
# 4              666  city_162                   0.767     Male
# ...            ...       ...                     ...      ...
# 19153         7386  city_173                   0.878     Male
# 19154        31398  city_103                   0.920     Male
# 19155        24576  city_103                   0.920     Male
# 19156         5756   city_65                   0.802     Male
# 19157        23834   city_67                   0.855  no_info
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 1       No relevent experience       no_enrollment        Graduate
# ...

# %%
len(df)
# Out:
# 19158

# %%
len(age)
# Out:
# 19158

# %%
df.join() # соединяет по индексу

# %% [markdown]
# # Numpy - более низкоуровневая библиотека на основе которой работает Pandas

# %%
type(df['city_development_index'].values)
# Out:
# numpy.ndarray

# %%
import numpy as np

# %%
np.mean([1,2,3,4,5])
# Out:
# 3.0

# %%
np.random.normal()
# Out:
# 0.7543625068862666

# %%
list(range(-10,10,0.5))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-467-38c4b0bafaa1> in <cell line: 1>()
# ----> 1 list(range(-10,10,0.5))
#
# TypeError: 'float' object cannot be interpreted as an integer

# %%
np.linspace(-10,10,100) # 100 точек в диапозоне
# Out:
# array([-10.        ,  -9.7979798 ,  -9.5959596 ,  -9.39393939,
#         -9.19191919,  -8.98989899,  -8.78787879,  -8.58585859,
#         -8.38383838,  -8.18181818,  -7.97979798,  -7.77777778,
#         -7.57575758,  -7.37373737,  -7.17171717,  -6.96969697,
#         -6.76767677,  -6.56565657,  -6.36363636,  -6.16161616,
#         -5.95959596,  -5.75757576,  -5.55555556,  -5.35353535,
#         -5.15151515,  -4.94949495,  -4.74747475,  -4.54545455,
#         -4.34343434,  -4.14141414,  -3.93939394,  -3.73737374,
#         -3.53535354,  -3.33333333,  -3.13131313,  -2.92929293,
#         -2.72727273,  -2.52525253,  -2.32323232,  -2.12121212,
#         -1.91919192,  -1.71717172,  -1.51515152,  -1.31313131,
#         -1.11111111,  -0.90909091,  -0.70707071,  -0.50505051,
#         -0.3030303 ,  -0.1010101 ,   0.1010101 ,   0.3030303 ,
#          0.50505051,   0.70707071,   0.90909091,   1.11111111,
#          1.31313131,   1.51515152,   1.71717172,   1.91919192,
# ...

# %%
np.random.uniform(size=10) / 100 # шум
# Out:
# array([0.00552958, 0.00424547, 0.00947937, 0.00598508, 0.0008768 ,
#        0.00458785, 0.00811775, 0.0091633 , 0.00888312, 0.00325345])

# %%
a = [1,2,3]
b = [2,2,2]

# %%
a+b
# Out:
# [1, 2, 3, 2, 2, 2]

# %%
a = np.array([1,2,3])
b = np.array([2,2,2])

# %%
a+b
# Out:
# array([3, 4, 5])

# %%
a
# Out:
# array([1, 2, 3])

# %%
pd.DataFrame(a)
# Out:
#    0
# 0  1
# 1  2
# 2  3
