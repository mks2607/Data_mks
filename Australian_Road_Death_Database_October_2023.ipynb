# %% [markdown]
# <a href="https://colab.research.google.com/github/mks2607/Data_mks/blob/mks2607/Australian_Road_Death_Database_October_2023.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df_fatalities = pd.read_csv('/content/ardd_fatalities.csv')
df_fatalities_clean = pd.read_csv('/content/ardd_fatalities_clean.csv')
# Out:
# <ipython-input-3-9c99ad7152b9>:1: DtypeWarning: Columns (10,14,15,16,17) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_fatalities = pd.read_csv('/content/ardd_fatalities.csv')

# %%
df_fatalities.head()
# Out:
#    Crash ID State  Month  Year   Dayweek   Time Crash Type Bus Involvement  \
# 0  20237008    NT     10  2023    Friday    NaN     Single              No
# 1  20234009    SA     10  2023  Saturday  03:00     Single              No
# 2  20233087   Qld     10  2023  Saturday  03:00     Single              No
# 3  20233149   Qld     10  2023    Sunday  03:00     Single              No
# 4  20233190   Qld     10  2023    Sunday  03:00   Multiple              No
#
#   Heavy Rigid Truck Involvement Articulated Truck Involvement  ...  \
# 0                            No                            No  ...
# 1                            No                            No  ...
# 2                            No                            No  ...
# 3                            No                            No  ...
# 4                            No                            No  ...
#
#   National Remoteness Areas                SA4 Name 2021  \
# ...

# %%
df_fatalities.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55360 entries, 0 to 55359
# Data columns (total 24 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Crash ID                       55360 non-null  int64
#  1   State                          55360 non-null  object
#  2   Month                          55360 non-null  int64
#  3   Year                           55360 non-null  int64
#  4   Dayweek                        55360 non-null  object
#  5   Time                           55307 non-null  object
#  6   Crash Type                     55355 non-null  object
#  7   Bus Involvement                55356 non-null  object
#  8   Heavy Rigid Truck Involvement  55356 non-null  object
#  9   Articulated Truck Involvement  55356 non-null  object
#  10  Speed Limit                    55360 non-null  object
#  11  Road User                      55360 non-null  object
# ...

# %%
df_fatalities_clean.head()
# Out:
#    Crash ID State   Dayweek Crash Type Bus Involvement  \
# 0  20234009    SA  Saturday     Single              No
# 1  20233087   Qld  Saturday     Single              No
# 2  20233149   Qld    Sunday     Single              No
# 3  20233190   Qld    Sunday   Multiple              No
# 4  20233052   Qld  Saturday     Single              No
#
#   Articulated Truck Involvement  Speed Limit         Road User  Gender  Age  \
# 0                            No          100            Driver    Male   22
# 1                            No           80            Driver    Male   19
# 2                            No           60         Passenger    Male   37
# 3                            No          100  Motorcycle rider    Male   35
# 4                            No           70            Driver  Female   32
#
#   Christmas Period Easter Period Age Group Day of week Time of day  \
# 0               No            No  17_to_25     Weekend       Night
# ...

# %%
df_fatalities_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53484 entries, 0 to 53483
# Data columns (total 19 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Crash ID                       53484 non-null  int64
#  1   State                          53484 non-null  object
#  2   Dayweek                        53484 non-null  object
#  3   Crash Type                     53484 non-null  object
#  4   Bus Involvement                53484 non-null  object
#  5   Articulated Truck Involvement  53484 non-null  object
#  6   Speed Limit                    53484 non-null  int64
#  7   Road User                      53484 non-null  object
#  8   Gender                         53484 non-null  object
#  9   Age                            53484 non-null  int64
#  10  Christmas Period               53484 non-null  object
#  11  Easter Period                  53484 non-null  object
# ...

# %%
df_merge = pd.merge(df_fatalities_clean,df_fatalities, on='Crash ID', how="outer") #обеденить таблицы d jlye

# %%
df_merge
# Out:
#         Crash ID State_x  Dayweek_x Crash Type_x Bus Involvement_x  \
# 0       19891001     NSW   Thursday     Multiple                No
# 1       19891002     NSW  Wednesday       Single                No
# 2       19891003     NSW     Sunday     Multiple                No
# 3       19891004     NSW     Friday       Single                No
# 4       19891005     NSW    Tuesday     Multiple                No
# ...          ...     ...        ...          ...               ...
# 69732  201750019     NaN        NaN          NaN               NaN
# 69733  201750029      WA    Tuesday       Single                No
# 69734  201850039      WA     Monday     Multiple                No
# 69735  201850049      WA     Sunday       Single                No
# 69736  201850059      WA  Wednesday       Single                No
#
#       Articulated Truck Involvement_x  Speed Limit_x       Road User_x  \
# 0                                  No          100.0         Passenger
# ...

# %%
df_merge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 69737 entries, 0 to 69736
# Data columns (total 42 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Crash ID                         69737 non-null  int64
#  1   State_x                          68065 non-null  object
#  2   Dayweek_x                        68065 non-null  object
#  3   Crash Type_x                     68065 non-null  object
#  4   Bus Involvement_x                68065 non-null  object
#  5   Articulated Truck Involvement_x  68065 non-null  object
#  6   Speed Limit_x                    68065 non-null  float64
#  7   Road User_x                      68065 non-null  object
#  8   Gender_x                         68065 non-null  object
#  9   Age_x                            68065 non-null  float64
#  10  Christmas Period_x               68065 non-null  object
#  11  Easter Period_x                  68065 non-null  object
# ...

# %%
df_merge.describe()
# Out:
#            Crash ID  Speed Limit_x         Age_x        Year_x          Hour  \
# count  6.973700e+04   68065.000000  68065.000000  68065.000000  68065.000000
# mean   2.005934e+07      85.065893     39.193021   2003.074737     12.575097
# std    2.177624e+06      20.291435     21.761079     10.082093      6.456334
# min    1.989100e+07       5.000000      0.000000   1989.000000      0.000000
# 25%    1.994323e+07      60.000000     21.000000   1994.000000      8.000000
# 50%    2.002147e+07     100.000000     34.000000   2002.000000     14.000000
# 75%    2.011303e+07     100.000000     55.000000   2011.000000     18.000000
# max    2.018501e+08     130.000000    101.000000   2023.000000     23.000000
#
#               Month        Year_y         Age_y  Unnamed: 23
# count  69737.000000  69737.000000  69737.000000          0.0
# mean       6.680012   2003.043119     38.980943          NaN
# std        3.498657     10.084545     21.881044          NaN
# ...

# %%
# удалить дубликаты колонок -удаляем по индексу.
df_merge = df_merge.drop(df_merge.columns[[19,21,22,24,25,27,28,29,30,31,36,37,38,39,40]], axis=1)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-14-5560181d117a> in <cell line: 2>()
#       1 # удалить дубликаты колонок -удаляем по индексу.
# ----> 2 df_merge = df_merge.drop(df_merge.columns[[19,21,22,24,25,27,28,29,30,31,36,37,38,39,40]], axis=1)
#       3 #
#       4 #
#       5 #
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in __getitem__(self, key)
#    5414                     )
#    5415
# -> 5416         result = getitem(key)
#    5417         # Because we ruled out integer above, we always get an arraylike here
#    5418         if result.ndim > 1:
#
# IndexError: index 27 is out of bounds for axis 0 with size 27

# %%
df_merge
# Out:
#         Crash ID State_x  Dayweek_x Crash Type_x Bus Involvement_x  \
# 0       19891001     NSW   Thursday     Multiple                No
# 1       19891002     NSW  Wednesday       Single                No
# 2       19891003     NSW     Sunday     Multiple                No
# 3       19891004     NSW     Friday       Single                No
# 4       19891005     NSW    Tuesday     Multiple                No
# ...          ...     ...        ...          ...               ...
# 69732  201750019     NaN        NaN          NaN               NaN
# 69733  201750029      WA    Tuesday       Single                No
# 69734  201850039      WA     Monday     Multiple                No
# 69735  201850049      WA     Sunday       Single                No
# 69736  201850059      WA  Wednesday       Single                No
#
#       Articulated Truck Involvement_x  Speed Limit_x       Road User_x  \
# 0                                  No          100.0         Passenger
# ...

# %%
# количестов смертей в каждом штате

df_merge_state = df_merge.groupby('State_x')['Crash ID'].count().reset_index()
df_merge_state
# Out:
#   State_x  Crash ID
# 0     ACT       182
# 1     NSW     22140
# 2      NT      1374
# 3     Qld     13896
# 4      SA      5995
# 5     Tas      2085
# 6     Vic     14592
# 7      WA      7801

# %%
# определим в какой день недели чеще всего погибают
df_merge_day = df_merge.groupby('Dayweek_x')['Crash ID'].count().reset_index()
df_merge_day
# Out:
#    Dayweek_x  Crash ID
# 0     Friday     12221
# 1     Monday      7582
# 2   Saturday     12306
# 3     Sunday     11048
# 4   Thursday      8724
# 5    Tuesday      7822
# 6  Wednesday      8362

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='Dayweek_x', y='Crash ID', data=df, palette='viridis')

plt.title('Количество аварий по дням недели', fontsize=10)
plt.xlabel('День недели', fontsize=10)
plt.ylabel('Количество аварий (Crash ID)', fontsize=10)
plt.xticks(rotation=40)
plt.grid(axis='y')

# Показать график
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-46-a1e675df6523>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Dayweek_x', y='Crash ID', data=df, palette='viridis')

# %%
# определить в какой час (в течении дня) чаще всего погибают
df_merge_hour = df_merge.groupby('Hour')['Crash ID'].count().reset_index()
df_merge_hour
# Out:
#     Hour  Crash ID
# 0    0.0      2248
# 1    1.0      2125
# 2    2.0      1802
# 3    3.0      2645
# 4    4.0      1702
# 5    5.0      1665
# 6    6.0      2205
# 7    7.0      2200
# 8    8.0      2412
# 9    9.0      2355
# 10  10.0      3000
# 11  11.0      3051
# 12  12.0      3100
# 13  13.0      3511
# 14  14.0      3830
# 15  15.0      4711
# 16  16.0      4079
# 17  17.0      3938
# 18  18.0      3622
# 19  19.0      3141
# 20  20.0      2841
# 21  21.0      2629
# 22  22.0      2616
# 23  23.0      2637

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='Hour', y='Crash ID', data=df_merge_hour, palette='viridis')

plt.title('Количество аварий по часам', fontsize=10)
plt.xlabel('Время', fontsize=10)
plt.ylabel('Количество аварий (Crash ID)', fontsize=10)
plt.xticks(rotation=40)
plt.grid(axis='y')

# Показать график
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-44-e1ea05411360>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Hour', y='Crash ID', data=df_merge_hour, palette='viridis')

# %%
# какой пол и возраст чаще всего погибает
plt.figure(figsize=(10, 6))
sns.barplot(x='Gender_x', y='Age_x', data=df_merge, palette='viridis')

plt.title('Распределение смертности по полу', fontsize=10)
plt.xlabel('Gender', fontsize=10)
plt.ylabel('Средий возраст', fontsize=10)
plt.xticks(rotation=40)
plt.grid(axis='y')

# Показать график
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-49-ed9d78a312ca>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Gender_x', y='Age_x', data=df_merge, palette='viridis')

# %%
# кто чаще погибает (пасажир/водитель/ мото и тд)
df_merge_type_drive = df_merge.groupby(['Road User_x','Age_x','Gender_x'])['Crash ID'].count()
df_merge_type_drive
# Out:
# Road User_x  Age_x  Gender_x
# Driver       0.0    Female      1
#                     Male        3
#              7.0    Male        1
#              11.0   Female      1
#                     Male        1
#                                ..
# Pedestrian   97.0   Male        4
#              98.0   Male        1
#              99.0   Female      1
#                     Male        1
#              100.0  Male        1
# Name: Crash ID, Length: 978, dtype: int64

# %%
df_sorted = df_merge_type_drive.sort_values(ascending=True)
df_sorted
# Out:
# Road User_x       Age_x  Gender_x
# Driver            0.0    Female        1
# Motorcycle rider  84.0   Female        1
#                   73.0   Female        1
#                   71.0   Female        1
#                   68.0   Female        1
#                                     ...
# Driver            22.0   Male        674
#                   21.0   Male        725
#                   20.0   Male        826
#                   19.0   Male        889
#                   18.0   Male        897
# Name: Crash ID, Length: 978, dtype: int64

# %%
len(df_merge['Road User_x'].unique())
# Out:
# 7
