# %% [markdown]
# <a href="https://colab.research.google.com/github/mks2607/Data_Scientist/blob/mks2607/suicides_no.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/bank.csv')

# %%
df.head()
# Out:
#    country  year     sex          age  suicides_no  population  \
# 0  Albania  1987    male  15-24 years           21      312900
# 1  Albania  1987    male  35-54 years           16      308000
# 2  Albania  1987  female  15-24 years           14      289700
# 3  Albania  1987    male    75+ years            1       21800
# 4  Albania  1987    male  25-34 years            9      274300
#
#    suicides/100k pop country-year  HDI for year  gdp_for_year ($)   \
# 0               6.71  Albania1987           NaN      2,156,624,900
# 1               5.19  Albania1987           NaN      2,156,624,900
# 2               4.83  Albania1987           NaN      2,156,624,900
# 3               4.59  Albania1987           NaN      2,156,624,900
# 4               3.28  Albania1987           NaN      2,156,624,900
#
#    gdp_per_capita ($)       generation
# 0                 796     Generation X
# 1                 796           Silent
# 2                 796     Generation X
# ...

# %%
df.tail()
# Out:
#           country  year     sex          age  suicides_no  population  \
# 27815  Uzbekistan  2014  female  35-54 years          107     3620833
# 27816  Uzbekistan  2014  female    75+ years            9      348465
# 27817  Uzbekistan  2014    male   5-14 years           60     2762158
# 27818  Uzbekistan  2014  female   5-14 years           44     2631600
# 27819  Uzbekistan  2014  female  55-74 years           21     1438935
#
#        suicides/100k pop    country-year  HDI for year  gdp_for_year ($)   \
# 27815               2.96  Uzbekistan2014         0.675     63,067,077,179
# 27816               2.58  Uzbekistan2014         0.675     63,067,077,179
# 27817               2.17  Uzbekistan2014         0.675     63,067,077,179
# 27818               1.67  Uzbekistan2014         0.675     63,067,077,179
# 27819               1.46  Uzbekistan2014         0.675     63,067,077,179
#
#        gdp_per_capita ($)    generation
# 27815                2309  Generation X
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27820 entries, 0 to 27819
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   country             27820 non-null  object
#  1   year                27820 non-null  int64
#  2   sex                 27820 non-null  object
#  3   age                 27820 non-null  object
#  4   suicides_no         27820 non-null  int64
#  5   population          27820 non-null  int64
#  6   suicides/100k pop   27820 non-null  float64
#  7   country-year        27820 non-null  object
#  8   HDI for year        8364 non-null   float64
#  9    gdp_for_year ($)   27820 non-null  object
#  10  gdp_per_capita ($)  27820 non-null  int64
#  11  generation          27820 non-null  object
# dtypes: float64(2), int64(4), object(6)
# memory usage: 2.5+ MB

# %%
df = df.fillna(0) #заполнение пустых значений 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27820 entries, 0 to 27819
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   country             27820 non-null  object
#  1   year                27820 non-null  int64
#  2   sex                 27820 non-null  object
#  3   age                 27820 non-null  object
#  4   suicides_no         27820 non-null  int64
#  5   population          27820 non-null  int64
#  6   suicides/100k pop   27820 non-null  float64
#  7   country-year        27820 non-null  object
#  8   HDI for year        27820 non-null  float64
#  9    gdp_for_year ($)   27820 non-null  object
#  10  gdp_per_capita ($)  27820 non-null  int64
#  11  generation          27820 non-null  object
# dtypes: float64(2), int64(4), object(6)
# memory usage: 2.5+ MB

# %%
#Удаляем все буквы - что бы оставить только год исследования

df['country-year'] = df['country-year'].str.replace(r'[a-zA-Z]', '',regex=True)

# %%
df['country-year'] = df['country-year'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27820 entries, 0 to 27819
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   country             27820 non-null  object
#  1   year                27820 non-null  int64
#  2   sex                 27820 non-null  object
#  3   age                 27820 non-null  object
#  4   suicides_no         27820 non-null  int64
#  5   population          27820 non-null  int64
#  6   suicides/100k pop   27820 non-null  float64
#  7   country-year        27820 non-null  int64
#  8   HDI for year        27820 non-null  float64
#  9    gdp_for_year ($)   27820 non-null  object
#  10  gdp_per_capita ($)  27820 non-null  int64
#  11  generation          27820 non-null  object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 2.5+ MB

# %%
df.head(3)
# Out:
#    country  year     sex          age  suicides_no  population  \
# 0  Albania  1987    male  15-24 years           21      312900
# 1  Albania  1987    male  35-54 years           16      308000
# 2  Albania  1987  female  15-24 years           14      289700
#
#    suicides/100k pop  country-year  HDI for year  gdp_for_year ($)   \
# 0               6.71          1987           0.0      2,156,624,900
# 1               5.19          1987           0.0      2,156,624,900
# 2               4.83          1987           0.0      2,156,624,900
#
#    gdp_per_capita ($)    generation
# 0                 796  Generation X
# 1                 796        Silent
# 2                 796  Generation X

# %%
print(df.columns)
# Out:
# Index(['country', 'year', 'sex', 'age', 'suicides_no', 'population',
#        'suicides/100k pop', 'country-year', 'HDI for year',
#        ' gdp_for_year ($) ', 'gdp_per_capita ($)', 'generation'],
#       dtype='object')

# %%
df.sort_values(by='population',ascending=False).head(4)
# Out:
#              country  year     sex          age  suicides_no  population  \
# 27105  United States  2006  female  35-54 years         3376    43805214
# 27117  United States  2007  female  35-54 years         3525    43607902
# 27093  United States  2005  female  35-54 years         3209    43509335
# 27081  United States  2004  female  35-54 years         3399    43240905
#
#        suicides/100k pop  country-year  HDI for year   gdp_for_year ($)   \
# 27105               7.71          2006         0.000  13,855,888,000,000
# 27117               8.08          2007         0.000  14,477,635,000,000
# 27093               7.38          2005         0.897  13,093,726,000,000
# 27081               7.86          2004         0.000  12,274,928,000,000
#
#        gdp_per_capita ($) generation
# 27105               49666    Boomers
# 27117               51585    Boomers
# 27093               47423    Boomers
# 27081               44867    Boomers

# %%
df.sort_values(by='suicides_no',ascending=False).head(4)
# Out:
#                   country  year   sex          age  suicides_no  population  \
# 20996  Russian Federation  1994  male  35-54 years        22338    19044200
# 21008  Russian Federation  1995  male  35-54 years        21706    19249600
# 21080  Russian Federation  2001  male  35-54 years        21262    21476420
# 21068  Russian Federation  2000  male  35-54 years        21063    21378098
#
#        suicides/100k pop  country-year  HDI for year  gdp_for_year ($)   \
# 20996             117.30          1994           0.0    395,077,301,248
# 21008             112.76          1995           0.0    395,531,066,563
# 21080              99.00          2001           0.0    306,602,673,980
# 21068              98.53          2000           0.0    259,708,496,267
#
#        gdp_per_capita ($) generation
# 20996                2853    Boomers
# 21008                2844    Boomers
# 21080                2229    Boomers
# 21068                1879    Boomers

# %%
df = df.drop(df.columns[[7]],axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27820 entries, 0 to 27819
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   country             27820 non-null  object
#  1   year                27820 non-null  int64
#  2   sex                 27820 non-null  object
#  3   age                 27820 non-null  object
#  4   suicides_no         27820 non-null  int64
#  5   population          27820 non-null  int64
#  6   suicides/100k pop   27820 non-null  float64
#  7   HDI for year        27820 non-null  float64
#  8    gdp_for_year ($)   27820 non-null  object
#  9   gdp_per_capita ($)  27820 non-null  int64
#  10  generation          27820 non-null  object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 2.3+ MB

# %%
df.head(3)
# Out:
#    country  year     sex          age  suicides_no  population  \
# 0  Albania  1987    male  15-24 years           21      312900
# 1  Albania  1987    male  35-54 years           16      308000
# 2  Albania  1987  female  15-24 years           14      289700
#
#    suicides/100k pop  HDI for year  gdp_for_year ($)   gdp_per_capita ($)  \
# 0               6.71           0.0      2,156,624,900                 796
# 1               5.19           0.0      2,156,624,900                 796
# 2               4.83           0.0      2,156,624,900                 796
#
#      generation
# 0  Generation X
# 1        Silent
# 2  Generation X

# %%
df.groupby('country').sum()
#освоить групбай - что были читаемые данные.
# Out:
#                         year  \
# country
# Albania               527796
# Antigua and Barbuda   647832
# Argentina             744000
# Armenia               596832
# Aruba                 336720
# ...                      ...
# United Arab Emirates  144540
# United Kingdom        744000
# United States         744000
# Uruguay               672072
# Uzbekistan            528348
#
#                                                                     sex  \
# country
# Albania               malemalefemalemalemalefemalefemalefemalemalefe...
# Antigua and Barbuda   femalefemalefemalefemalefemalefemalemalemalema...
# Argentina             malemalemalefemalemalefemalemalefemalefemalefe...
# Armenia               malemalemalemalefemalemalefemalefemalefemalefe...
# Aruba                 malemalemalemalefemalefemalefemalefemalefemale...
# ...                                                                 ...
# United Arab Emirates  malemalefemalemalefemalemalefemalefemalefemale...
# ...
