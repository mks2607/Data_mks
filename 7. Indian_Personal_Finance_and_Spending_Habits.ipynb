# %% [markdown]
# <a href="https://colab.research.google.com/github/mks2607/Data_Scientist/blob/mks2607/Indian_Personal_Finance_and_Spending_Habits.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/Indian Personal Finance and Spending Habits.csv')
df
# Out:
#               Income  Age  Dependents     Occupation City_Tier          Rent  \
# 0       44637.249636   49           0  Self_Employed    Tier_1  13391.174891
# 1       26858.596592   34           2        Retired    Tier_2   5371.719318
# 2       50367.605084   35           1        Student    Tier_3   7555.140763
# 3      101455.600247   21           0  Self_Employed    Tier_3  15218.340037
# 4       24875.283548   52           4   Professional    Tier_2   4975.056710
# ...              ...  ...         ...            ...       ...           ...
# 19995   40913.466178   51           4  Self_Employed    Tier_1  12274.039853
# 19996   90295.772638   21           1        Student    Tier_2  18059.154528
# 19997   40604.567373   30           1   Professional    Tier_2   8120.913475
# 19998  118157.817240   27           2   Professional    Tier_1  35447.345172
# 19999    8209.249769   62           3   Professional    Tier_1   2462.774931
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 27 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Income                           20000 non-null  float64
#  1   Age                              20000 non-null  int64
#  2   Dependents                       20000 non-null  int64
#  3   Occupation                       20000 non-null  object
#  4   City_Tier                        20000 non-null  object
#  5   Rent                             20000 non-null  float64
#  6   Loan_Repayment                   20000 non-null  float64
#  7   Insurance                        20000 non-null  float64
#  8   Groceries                        20000 non-null  float64
#  9   Transport                        20000 non-null  float64
#  10  Eating_Out                       20000 non-null  float64
# ...

# %%
df = df.round(2)

# %%
df
# Out:
#           Income  Age  Dependents     Occupation City_Tier      Rent  \
# 0       44637.25   49           0  Self_Employed    Tier_1  13391.17
# 1       26858.60   34           2        Retired    Tier_2   5371.72
# 2       50367.61   35           1        Student    Tier_3   7555.14
# 3      101455.60   21           0  Self_Employed    Tier_3  15218.34
# 4       24875.28   52           4   Professional    Tier_2   4975.06
# ...          ...  ...         ...            ...       ...       ...
# 19995   40913.47   51           4  Self_Employed    Tier_1  12274.04
# 19996   90295.77   21           1        Student    Tier_2  18059.15
# 19997   40604.57   30           1   Professional    Tier_2   8120.91
# 19998  118157.82   27           2   Professional    Tier_1  35447.35
# 19999    8209.25   62           3   Professional    Tier_1   2462.77
#
#        Loan_Repayment  Insurance  Groceries  Transport  ...  Desired_Savings  \
# ...

# %%
from matplotlib import pyplot as plt
df.plot(kind='scatter', x='Rent', y='Loan_Repayment', s=32, alpha=.8)
plt.gca().spines[['top', 'left',]].set_visible(True)

# %%
from matplotlib import pyplot as plt
df.plot(kind='scatter', x='Income', y='Age', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
df.plot(kind='scatter', x='Income', y='Dependents', s=60, alpha=0.9)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
df.head(5)
# Out:
#       Income  Age  Dependents     Occupation City_Tier      Rent  \
# 0   44637.25   49           0  Self_Employed    Tier_1  13391.17
# 1   26858.60   34           2        Retired    Tier_2   5371.72
# 2   50367.61   35           1        Student    Tier_3   7555.14
# 3  101455.60   21           0  Self_Employed    Tier_3  15218.34
# 4   24875.28   52           4   Professional    Tier_2   4975.06
#
#    Loan_Repayment  Insurance  Groceries  Transport  ...  Desired_Savings  \
# 0            0.00    2206.49    6658.77    2636.97  ...          6200.54
# 1            0.00     869.52    2818.44    1543.02  ...          1923.18
# 2         4612.10    2201.80    6313.22    3221.40  ...          7050.36
# 3         6809.44    4889.42   14690.15    7106.13  ...         16694.97
# 4         3112.61     635.91    3034.33    1276.16  ...          1874.10
#
#    Disposable_Income  Potential_Savings_Groceries  \
# 0           11265.63                      1685.70
# ...

# %%
df.loc[1,'Occupation']
# Out:
# 'Retired'

# %%
df.iloc[1,2]
# Out:
# 2

# %%
df = df[df['Age'] == 40]

df
# Out:
#          Income  Age  Dependents     Occupation City_Tier      Rent  \
# 7      55431.34   40           1   Professional    Tier_2  11086.27
# 292    18722.12   40           2        Student    Tier_1   5616.64
# 320    32420.60   40           3        Student    Tier_2   6484.12
# 341    36457.50   40           2   Professional    Tier_3   5468.62
# 350    38471.72   40           2  Self_Employed    Tier_1  11541.52
# ...         ...  ...         ...            ...       ...       ...
# 19692  41902.37   40           3        Student    Tier_3   6285.36
# 19759   9820.63   40           1        Retired    Tier_2   1964.13
# 19814  14074.23   40           1        Retired    Tier_3   2111.14
# 19842  64216.71   40           1  Self_Employed    Tier_2  12843.34
# 19906  11181.29   40           3        Retired    Tier_1   3354.39
#
#        Loan_Repayment  Insurance  Groceries  Transport  ...  Desired_Savings  \
# ...

# %%
print(df['Occupation'].unique())
# Out:
# ['Professional' 'Student' 'Self_Employed' 'Retired']

# %%
df = df[(df['Occupation'] == 'Student') | (df['Occupation'] == 'Retired')]

df
# Out:
#          Income  Age  Dependents Occupation City_Tier      Rent  \
# 292    18722.12   40           2    Student    Tier_1   5616.64
# 320    32420.60   40           3    Student    Tier_2   6484.12
# 763    27780.92   40           0    Student    Tier_2   5556.18
# 890    57834.36   40           3    Retired    Tier_1  17350.31
# 934    42657.75   40           1    Retired    Tier_3   6398.66
# ...         ...  ...         ...        ...       ...       ...
# 19521  26665.79   40           4    Retired    Tier_2   5333.16
# 19692  41902.37   40           3    Student    Tier_3   6285.36
# 19759   9820.63   40           1    Retired    Tier_2   1964.13
# 19814  14074.23   40           1    Retired    Tier_3   2111.14
# 19906  11181.29   40           3    Retired    Tier_1   3354.39
#
#        Loan_Repayment  Insurance  Groceries  Transport  ...  Desired_Savings  \
# 292           2305.34     480.67    2590.77    1192.26  ...          1518.16
# ...

# %%
df.sort_values(by='Income',ascending=True)
# Out:
#           Income  Age  Dependents Occupation City_Tier      Rent  \
# 6723     4083.48   40           1    Retired    Tier_2    816.70
# 11867    5061.64   40           3    Student    Tier_2   1012.33
# 16133    5650.36   40           1    Retired    Tier_1   1695.11
# 4338     5757.34   40           1    Retired    Tier_1   1727.20
# 1286     6904.91   40           3    Student    Tier_1   2071.47
# ...          ...  ...         ...        ...       ...       ...
# 8744   154809.44   40           0    Retired    Tier_1  46442.83
# 5961   161650.29   40           3    Student    Tier_1  48495.09
# 6106   194699.93   40           1    Retired    Tier_2  38939.99
# 19058  197347.57   40           4    Retired    Tier_1  59204.27
# 5204   201656.99   40           0    Retired    Tier_2  40331.40
#
#        Loan_Repayment  Insurance  Groceries  Transport  ...  Desired_Savings  \
# 6723           242.87     167.57     591.38     262.17  ...           238.88
# ...

# %%
df['Income'].max()
# Out:
# 201656.99

# %%
df['Income'].min()
# Out:
# 4083.48

# %%
df.max()
# Out:
# Income                             201656.99
# Age                                       40
# Dependents                                 4
# Occupation                           Student
# City_Tier                             Tier_3
# Rent                                59204.27
# Loan_Repayment                      37798.11
# Insurance                            9327.47
# Groceries                           26000.79
# Transport                           14119.39
# Eating_Out                           9534.46
# Entertainment                        9099.11
# Utilities                           15126.06
# Healthcare                           9561.91
# Education                           19055.29
# Miscellaneous                        5864.23
# Desired_Savings_Percentage             24.78
# Desired_Savings                     37333.81
# Disposable_Income                   49175.51
# Potential_Savings_Groceries          7358.84
# Potential_Savings_Transport          3688.13
# ...

# %%
df.min()
# Out:
# Income                             4083.48
# Age                                     40
# Dependents                               0
# Occupation                         Retired
# City_Tier                           Tier_1
# Rent                                 816.7
# Loan_Repayment                         0.0
# Insurance                           153.56
# Groceries                           591.38
# Transport                           262.17
# Eating_Out                          115.75
# Entertainment                       114.77
# Utilities                            199.6
# Healthcare                          148.75
# Education                              0.0
# Miscellaneous                        55.81
# Desired_Savings_Percentage            5.03
# Desired_Savings                        0.0
# Disposable_Income                  -321.15
# Potential_Savings_Groceries          71.84
# Potential_Savings_Transport          26.38
# Potential_Savings_Eating_Out          9.88
# ...

# %%
df
# Out:
#          Income  Age  Dependents Occupation City_Tier      Rent  \
# 292    18722.12   40           2    Student    Tier_1   5616.64
# 320    32420.60   40           3    Student    Tier_2   6484.12
# 763    27780.92   40           0    Student    Tier_2   5556.18
# 890    57834.36   40           3    Retired    Tier_1  17350.31
# 934    42657.75   40           1    Retired    Tier_3   6398.66
# ...         ...  ...         ...        ...       ...       ...
# 19521  26665.79   40           4    Retired    Tier_2   5333.16
# 19692  41902.37   40           3    Student    Tier_3   6285.36
# 19759   9820.63   40           1    Retired    Tier_2   1964.13
# 19814  14074.23   40           1    Retired    Tier_3   2111.14
# 19906  11181.29   40           3    Retired    Tier_1   3354.39
#
#        Loan_Repayment  Insurance  Groceries  Transport  ...  Desired_Savings  \
# 292           2305.34     480.67    2590.77    1192.26  ...          1518.16
# ...

# %%
grouped_max = df.groupby('Occupation').max()

grouped_max
# Out:
#                Income  Age  Dependents City_Tier      Rent  Loan_Repayment  \
# Occupation
# Retired     201656.99   40           4    Tier_3  59204.27        37798.11
# Student     161650.29   40           4    Tier_3  48495.09        19158.68
#
#             Insurance  Groceries  Transport  Eating_Out  ...  Desired_Savings  \
# Occupation                                               ...
# Retired       9327.47   26000.79   14119.39     9534.46  ...         37333.81
# Student       7408.43   20185.01   10439.66     7032.91  ...         29050.86
#
#             Disposable_Income  Potential_Savings_Groceries  \
# Occupation
# Retired              44139.19                      7358.84
# Student              49175.51                      4332.80
#
#             Potential_Savings_Transport  Potential_Savings_Eating_Out  \
# Occupation
# Retired                         3688.13                       2787.36
# Student                         2394.72                       1587.18
#
# ...

# %% [markdown]
# #**GROURBY**

# %%
grouped_sum = df.groupby('City_Tier').sum()
grouped_min = df.groupby('City_Tier').min()


grouped_min
# Out:
#             Income  Age  Dependents Occupation     Rent  Loan_Repayment  \
# City_Tier
# Tier_1     5650.36   40           0    Retired  1695.11             0.0
# Tier_2     4083.48   40           0    Retired   816.70             0.0
# Tier_3     7343.15   40           0    Retired  1101.47             0.0
#
#            Insurance  Groceries  Transport  Eating_Out  ...  Desired_Savings  \
# City_Tier                                               ...
# Tier_1        153.56     665.64     337.12      171.53  ...             0.00
# Tier_2        167.57     591.38     262.17      115.75  ...           238.88
# Tier_3        226.99     974.76     452.93      254.16  ...           602.95
#
#            Disposable_Income  Potential_Savings_Groceries  \
# City_Tier
# Tier_1               -321.15                       100.89
# Tier_2                778.09                        71.84
# Tier_3               2278.85                        82.39
#
# ...

# %%
result = df.groupby('City_Tier').agg(['sum', 'min','max', 'count'])
result
# Out:
#                Income                             Age                \
#                   sum      min        max count   sum min max count
# City_Tier
# Tier_1     3137643.19  5650.36  197347.57    65  2600  40  40    65
# Tier_2     4630446.99  4083.48  201656.99   121  4840  40  40   121
# Tier_3     1199832.12  7343.15   99664.07    39  1560  40  40    39
#
#           Dependents      ... Potential_Savings_Healthcare        \
#                  sum min  ...                          max count
# City_Tier                 ...
# Tier_1           130   0  ...                       236.99    65
# Tier_2           244   0  ...                       305.74   121
# Tier_3            89   0  ...                       169.19    39
#
#           Potential_Savings_Education                     \
#                                   sum  min     max count
# City_Tier
# Tier_1                        4994.78  0.0  815.18    65
# Tier_2                        7184.66  0.0  380.78   121
# ...

# %%
result = df.groupby(['City_Tier', 'Occupation','Age']).mean()

result
# Out:
#                                 Income  Dependents          Rent  \
# City_Tier Occupation Age
# Tier_1    Retired    40   49838.613103    2.034483  14951.584138
#           Student    40   47008.983611    1.972222  14102.694722
# Tier_2    Retired    40   42238.860317    1.809524   8447.772222
#           Student    40   33955.151552    2.241379   6791.029828
# Tier_3    Retired    40   29012.350000    2.210526   4351.851579
#           Student    40   32429.873500    2.350000   4864.481000
#
#                           Loan_Repayment    Insurance    Groceries  \
# City_Tier Occupation Age
# Tier_1    Retired    40      3433.538966  1693.896552  6302.085862
#           Student    40      2851.203056  1744.784722  5951.482778
# Tier_2    Retired    40      3223.858889  1511.057143  5232.680317
#           Student    40      2205.507241  1145.761897  4224.153448
# Tier_3    Retired    40      1488.589474   883.141053  3542.200526
# ...

# %%
def custom_func(x):
    return x.max() - x.min()

custom_agg = grouped['Income'].agg(custom_func)
custom_agg
# Out:
# Rent
# 816.70      0.0
# 1012.33     0.0
# 1101.47     0.0
# 1352.26     0.0
# 1469.34     0.0
#            ...
# 40331.40    0.0
# 42451.73    0.0
# 46442.83    0.0
# 48495.09    0.0
# 59204.27    0.0
# Name: Income, Length: 225, dtype: float64

# %%
filtered = grouped.filter(lambda x: x['Rent'].max() == 5616.64)

filtered
# Out:
#        Income  Age  Dependents Occupation City_Tier     Rent  Loan_Repayment  \
# 292  18722.12   40           2    Student    Tier_1  5616.64         2305.34
#
#      Insurance  Groceries  Transport  ...  Desired_Savings  Disposable_Income  \
# 292     480.67    2590.77    1192.26  ...          1518.16            2279.65
#
#      Potential_Savings_Groceries  Potential_Savings_Transport  \
# 292                       747.44                       291.96
#
#      Potential_Savings_Eating_Out  Potential_Savings_Entertainment  \
# 292                        111.18                            92.62
#
#      Potential_Savings_Utilities  Potential_Savings_Healthcare  \
# 292                       119.44                         27.44
#
#      Potential_Savings_Education  Potential_Savings_Miscellaneous
# 292                        23.96                            58.49
#
# [1 rows x 27 columns]

# %%
transformed = grouped['City_Tier'].transform(lambda x: x + x.min())
transformed
# Out:
# 292      Tier_1Tier_1
# 320      Tier_2Tier_2
# 763      Tier_2Tier_2
# 890      Tier_1Tier_1
# 934      Tier_3Tier_3
#              ...
# 19521    Tier_2Tier_2
# 19692    Tier_3Tier_3
# 19759    Tier_2Tier_2
# 19814    Tier_3Tier_3
# 19906    Tier_1Tier_1
# Name: City_Tier, Length: 225, dtype: object

# %%
group_sizes = grouped['Loan_Repayment'].size()
group_sizes
# Out:
# Rent
# 816.70      1
# 1012.33     1
# 1101.47     1
# 1352.26     1
# 1469.34     1
#            ..
# 40331.40    1
# 42451.73    1
# 46442.83    1
# 48495.09    1
# 59204.27    1
# Name: Loan_Repayment, Length: 225, dtype: int64

# %%
reset_index = grouped['City_Tier'].sum().reset_index()
reset_index
# Out:
#          Rent City_Tier
# 0      816.70    Tier_2
# 1     1012.33    Tier_2
# 2     1101.47    Tier_3
# 3     1352.26    Tier_3
# 4     1469.34    Tier_3
# ..        ...       ...
# 220  40331.40    Tier_2
# 221  42451.73    Tier_1
# 222  46442.83    Tier_1
# 223  48495.09    Tier_1
# 224  59204.27    Tier_1
#
# [225 rows x 2 columns]

# %%
df
# Out:
#          Income  Age  Dependents Occupation City_Tier      Rent  \
# 292    18722.12   40           2    Student    Tier_1   5616.64
# 320    32420.60   40           3    Student    Tier_2   6484.12
# 763    27780.92   40           0    Student    Tier_2   5556.18
# 890    57834.36   40           3    Retired    Tier_1  17350.31
# 934    42657.75   40           1    Retired    Tier_3   6398.66
# ...         ...  ...         ...        ...       ...       ...
# 19521  26665.79   40           4    Retired    Tier_2   5333.16
# 19692  41902.37   40           3    Student    Tier_3   6285.36
# 19759   9820.63   40           1    Retired    Tier_2   1964.13
# 19814  14074.23   40           1    Retired    Tier_3   2111.14
# 19906  11181.29   40           3    Retired    Tier_1   3354.39
#
#        Loan_Repayment  Insurance  Groceries  Transport  ...  Desired_Savings  \
# 292           2305.34     480.67    2590.77    1192.26  ...          1518.16
# ...

# %% [markdown]
# Посвятить прямой эфир - изучению функции groupby
